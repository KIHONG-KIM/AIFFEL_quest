# %%
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# =3

# %% [markdown]
# # 1. 데이터 준비

# %% [markdown]
# ## 1.1 불용어 사전 다운로드

# %%
# NLTK를 사용해 불용어 다운로드 받기
import nltk
nltk.download('stopwords')

# %% [markdown]
# ## 1.2 데이터 불러오기

# %%
# 아마존 리뷰 데이터를 pandas 데이터프레임으로 불러오기
filepath = "./data/news_summarization/Reviews.csv"
data = pd.read_csv(filepath, nrows=100000)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 100000

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# # 2. 데이터 전처리

# %%
# 필요한 컬럼만 남기기
data = data[['Text', 'Summary']]
data.head()
# Out:
#                                                     Text  \
# 2941   This review will make me sound really stupid, ...
# 61038  I love these things. They are delicious. Basic...
# 90410  Never got item.  Followed up.  Nothin.  Follow...
# 41398  No particular thanks to Amazon, my cat enjoys ...
# 38189  The Beaba Multiportion Freezer Tray is perfect...
# 96776  My husband is a big coffee drinker. He enjoys ...
# 76073  These are a great snack to have around. They'r...
# 91373  What a complete rip off. People - just go down...
# 41497  I don't trust dog treats (or much else) from C...
# 72251  I am LOVING this... I finished my first bowlfu...
# 86968  This is my go-to brand and flavor, since I can...
# 66065  As others reviewers have mentioned, these real...
# 28375  Absolutely our dogs very favorite treats. They...
# 63259  I have tried microwave cakes in the past and w...
# 79620  My maltipoo named Elvis Lee just absolutely lo...
#
#                                                  Summary
# 2941   Filler food is empty, leaves your cat always n...
# 61038                               I Love the Mallomars
# 90410                            Charged... Never Got It
# 41398                                       Cat's choicw
# 38189                              Perfect for baby food
# 96776                                       Great flavor
# 76073                                              Tasty
# 91373                                            No Way.
# 41497                 great product but it is from China
# 72251                                   Seriously Yummy!
# 86968                                 Great alternative.
# 66065                      Smelly but good (for the dog)
# 28375                                         dog treats
# 63259                        These are pretty darn good.
# 79620                                Milk Bone Trail Mix

# %%
#랜덤한 15개 샘플 출력
data.sample(15)

# %% [markdown]
# ## 2.1 중복 제거

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
# 참고로, Summary 컬럼은 요약 내용이므로 당연히 중복이 있을 수 있음!
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348

# %%
# [주의] Summary 컬럼은 당연히 중복이 있을 수 있음! (그래서, 아래에서 Text 컬럼만 중복 제거하는 것임)
# inplace=True 를 설정하면 새로운 DataFrame 타입 객체로 리턴하지 않고, 원본인 data 객체 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['Text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88426

# %% [markdown]
# ## 2.2 NULL 제거

# %%
# NULL 확인
print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
# NULL 제거
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88425

# %% [markdown]
# ## 2.3 종합적인 데이터 전처리 실시
# - 대문자 --> 소문자로 변환
# - HTML 태그 제거
# - 괄호로 닫힌 문자열 모두 제거
# - 쌍따옴표 제거
# - 약어 정규화
#   - 텍스트 데이터에 있어서 '약어 정규화 처리'는 영어 기준으로는 didn't --> did not 으로 일원화 시키는 것을 의미함.
#   - 약어와 풀네임이 함께 사용된 경우 풀네임으로 일원화 하거나 약어로 일원화하거나 약어와 풀네임을 함께 사용하거나 등을 정해서 처리해도 될 듯.
# - 소유격 제거
# - 영어 외 문자 --> 공백(" ")으로 변환
# - m이 3개 이상 사용되면 'mm' 으로 변환
# - 불용어 제거
#   - 여기에서는 Text 컬럼에 대해서는 불용어 제거, Summary 컬럼에 대해서는 불용어 제거하지 않음.

# %%
# 약어 정규화 준비
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
# 미리 다운받아 두었던 NLTK 불용어(stopwords) 사전 확인
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수 정의
# 파라미터로 넘어오는 remove_stopwords 값을 기준으로 불용어 제거 여부를 결정.
# 여기에서는 Text 컬럼에 대해서는 불용어를 제거하고, Summary 컬럼에 대해서는 불용어 제거하지 않음.
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.strip() # [김주현 추가] 좌우 공백 제거
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah

    # 불용어 제거 (Text 컬럼)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary 컬럼)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens
print('=3')
# Out:
# =3

# %%
# 데이터 전처리 함수 테스트하기
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("summary:", preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# summary: great way to start the day

# %%
# Text 컬럼 전체 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다.
clean_text = []

for sentence in data['Text']:
    processed_sentence = preprocess_sentence(sentence)
    clean_text.append(processed_sentence)

# # 아래처럼 map 함수 이용해서 처리해도 됨. (for 반복문에 비해 일반적으로 더 빠르게 처리됨) --> 실제로 해 보니 오히려 더 느렸음!(로컬 노트북 기준)
# data['Processed_Text'] = data['Text'].map(lambda x: preprocess_sentence(x))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# C:\Users\freen\AppData\Local\Temp\ipykernel_27172\2884123602.py:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# Text 전처리 후 결과:  ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better', 'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo', 'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch', 'looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal', 'great taffy great price wide assortment yummy taffy delivery quick taffy lover deal']

# %%
# # 아래처럼 map 함수 이용해서 처리해도 됨. (for 반복문에 비해 일반적으로 더 빠르게 처리됨)
# # => 실제로 해보니 무슨 이유에서인지 더 오래 걸림. (73분 정도 소요)
# processed_text = data['Text'].map(lambda x: preprocess_sentence(x))
# Out:
# C:\Users\freen\AppData\Local\Temp\ipykernel_27172\2884123602.py:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거

# %%
# processed_text
# Out:
# 0        bought several vitality canned dog food produc...
# 1        product arrived labeled jumbo salted peanuts p...
# 2        confection around centuries light pillowy citr...
# 3        looking secret ingredient robitussin believe f...
# 4        great taffy great price wide assortment yummy ...
#                                ...
# 99995                   love buy another box done last one
# 99996    late father law used rating system meals parti...
# 99997    favorite brand korean ramen spicy used eating ...
# 99998    like noodles although say spicy somewhat under...
# 99999    love noodle twice week amazing thing feel well...
# Name: Text, Length: 88425, dtype: object

# %%
len(clean_text)
# Out:
# 88425

# %%
# 5개 샘플만 처리 결과 확인해 보기
for i in range(5):
    print(clean_text[i])
# Out:
# bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better
# product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo
# confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch
# looking secret ingredient robitussin believe found got addition root beer extract ordered made cherry soda flavor medicinal
# great taffy great price wide assortment yummy taffy delivery quick taffy lover deal

# %%
# Summary 컬럼 전체 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다.
clean_summary = []

for sentence in data['Summary']:
    processed_sentence = preprocess_sentence(sentence, False)   # Summary 컬럼의 경우 불용어 제거하지 않음!
    clean_summary.append(processed_sentence)

# # 아래처럼 map 함수 이용해서 처리해도 됨. (for 반복문에 비해 일반적으로 더 빠르게 처리됨) --> 실제로 해 보니 오히려 더 느렸음!(로컬 노트북 기준)
# data['Processed_Summary'] = data['Summary'].map(lambda x: preprocess_sentence(x, False))

print("Summary 전처리 후 결과: ", clean_summary[:5])
# Out:
# C:\Users\freen\AppData\Local\Temp\ipykernel_27172\2884123602.py:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# C:\Users\freen\AppData\Local\Temp\ipykernel_27172\2884123602.py:4: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
# Summary 전처리 후 결과:  ['good quality dog food', 'not as advertised', 'delight says it all', 'cough medicine', 'great taffy']

# %%
# 전처리 결과를 원본 Series 객체로 업데이트
data['Text'] = clean_text
data['Summary'] = clean_summary
# Out:
# =3

# %%
# [중요] 전처리 이후에는 원본 데이터에서 제거되는 것들이 많다보니 이전에 NULL 처리를 완료했더라도 전처리 이후에는 NULL 값이 새롭게 생길 수 있음!
# 빈 값을 Null 값으로 변환(아래에서 isnull() 메소드를 통해 간단히 처리하기 위해)
data.replace('', np.nan, inplace=True)

# %%
# 전처리 이후에 새롭게 생긴 NULL 데이터 확인
data.isnull().sum()
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
# NULL 행 제거
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88355

# %% [markdown]
# ## 2.4 데이터별 threshold 결정하고 처리하기

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(summary_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.792428272310566
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010729443721352

# %%
# 그래프를 보고 threshold 값을 임의로 정해 봄.
text_max_len = 50
summary_max_len = 8
# Out:
# =3

# %%
# threshold 이하 샘플의 비율 계산 함수 정의:
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))
# Out:
# =3

# %%
# Text, Summary 컬럼 전체에 대해 임의로 정한 threshold 이하인 샘플의 비율 확인
below_threshold_len(text_max_len, data['Text'])
below_threshold_len(summary_max_len,  data['Summary'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.7745119121724859
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %%
# 필터링 조건 적용: Text, Summary 컬럼에서 threshold 이하인 샘플들만 남기고, threshold 초과하는 샘플들은 모두 제거
# [참고] 이러헥 하지 않고 threshold 초과하는 경우 초과하는 부분을 모두 삭제하되 샘플 자체는 유지하는 방법을 사용할 수도 있음.
# 하지만, 여기에서는 원문과 요약문의 관계여서 원문에서 threshold 초과 부분을 제거한 상태로 학습하는게 의미가 없을거 같다고 판단해 아예 샘플에서 제거하는 방법을 택한 것 같음.
data = data[
    data['Text'].apply(lambda x: len(x.split()) <= text_max_len) &
    data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)
]

print('전체 샘플수 :', (len(data)))

data
# Out:
# 전체 샘플수 : 65818
#                                                     Text  \
# 0      bought several vitality canned dog food produc...
# 1      product arrived labeled jumbo salted peanuts p...
# 2      confection around centuries light pillowy citr...
# 3      looking secret ingredient robitussin believe f...
# 4      great taffy great price wide assortment yummy ...
# ...                                                  ...
# 99993  stuff awesome best flavor boil water drain wat...
# 99994               love noodle little spicy wife perfct
# 99995                 love buy another box done last one
# 99997  favorite brand korean ramen spicy used eating ...
# 99998  like noodles although say spicy somewhat under...
#
#                      Summary
# 0      good quality dog food
# 1          not as advertised
# 2        delight says it all
# 3             cough medicine
# 4                great taffy
# ...                      ...
# 99993            great stuff
# 99994             good stuff
# 99995                  yummy
# 99997            great ramen
# 99998                  spicy
#
# [65818 rows x 2 columns]

# %% [markdown]
# ## 2.5 타겟 데이터 추가 작업
# - <SOS> 토큰과 <EOS> 토큰 추가
# - 디코더의 입력용으로 사용되는 데이터에는 <SOS> 토큰 추가
# - 디코더의 출력 예측값에 대한 검증용 타겟 데이터(레이블 데이터)에는 <EOS> 토큰 추가

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %% [markdown]
# ## 2.6 넘파이 배열로 변환

# %%
# 넘파이 배열로 변환
encoder_input = np.array(data['Text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블
# Out:
# =3

# %%
print(encoder_input.shape)
print(decoder_input.shape)
print(decoder_target.shape)
# Out:
# (65818,)
# (65818,)
# (65818,)

# %% [markdown]
# ## 2.7 데이터 섞기(셔플링)

# %%
# 데이터 섞기(셔플링) 위한 인덱스 번호 리스트 준비해 셔플링: 인덱스 번호만 셔플링된 상태임.
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [29860  1342 49336 ... 24776 63616   315]

# %%
# [테스트] 인덱스 번호만 포함하고 있는 리스트를 활용해 리스트 데이터 필터링하기
temp_list = [0, 1, 2]
decoder_input[temp_list]
# Out:
# array(['sostoken good quality dog food', 'sostoken not as advertised',
#        'sostoken delight says it all'], dtype=object)

# %%
# 미리 셔플링해둔 indices 리스트를 활용해 실제 원본 데이터 리스트 섞기
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]
print('=3')
# Out:
# =3

# %% [markdown]
# ## 2.8 훈련용, 검증용 데이터셋 분할
# - [참고] 코드에서는 검증용 데이터셋을 계속 test 로 명명하고 있음.

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 13163

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 52655
# 훈련 레이블의 개수 : 52655
# 테스트 데이터의 개수 : 13163
# 테스트 레이블의 개수 : 13163

# %% [markdown]
# ## 2.9 토크나이징

# %% [markdown]
# ### 2.9.1 인코더 입력용으로 들어가는 훈련용 데이터 토크나이징

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
# Out:
# =3

# %%
# 등장 빈도수가 7회 미만인 단어들에 대한 여러가지 통계 정보 확인
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 31983
# 등장 빈도가 6번 이하인 희귀 단어의 수: 23714
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 8269
# 단어 집합에서 희귀 단어의 비율: 74.14563987118157
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.373124021258405

# %%
# 등장 빈도수가 7회 미만인 단어들은 제외해서 다시 한번 단어 집합 재생성
src_vocab = 8000    # 정확하게는 8,269개여야 하지만 대략 8,000개로 잡아 처리함.
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한(빈도수 기준으로 8,000등까지만 단어 집합에 포함됨)
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성
# Out:
# =3

# %% [markdown]
# ### 2.9.2 정수 시퀀스로 변환

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
# [참고] 검증용 데이터셋(encoder_input_test) 역시 훈련용 데이터셋 기준으로 생성한 단어 집합으로 정수 시퀀스 변환함!
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train)
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[3, 371, 836, 181, 135, 330, 429, 148, 76, 1725, 53, 4, 392, 26, 1022, 1279, 92, 42, 5], [114, 140, 36, 33, 499, 9, 230, 2, 36, 5655, 27, 1352, 318, 92, 5884, 2, 69, 305, 60], [48, 679, 501, 40, 83, 421, 178, 1548, 282, 18, 47]]

# %% [markdown]
# ### 2.9.3 디코더 입력용으로 들어가는 훈련용 데이터 토크나이징

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)   # 단어 집합 생성
# Out:
# =3

# %%
# Summary에 대해서는 등장 빈도수가 7 미만이 아니라 6 미만을 기준으로 처리: 임의로 정하는 것임
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 10522
# 등장 빈도가 5번 이하인 희귀 단어의 수: 8145
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 2377
# 단어 집합에서 희귀 단어의 비율: 77.40923778749287
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.944845806637608

# %%
tar_vocab = 2000    # 타겟 단어 집합은 2,000개로 제한
tar_tokenizer = Tokenizer(num_words=tar_vocab)
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)    # decoder_target_train 데이터에 대해서도 단어 집합에 추가!

# %% [markdown]
# ### 2.9.4 정수 시퀀스로 변환

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train)
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 3, 1801], [1, 90, 17], [1, 746, 356, 14], [1, 4], [1, 835]]
# target
# decoder  [[3, 1801, 2], [90, 17, 2], [746, 356, 14, 2], [4, 2], [835, 2]]

# %% [markdown]
# ### 2.9.5 최종적으로 스페셜 토큰만 남아있는 샘플 제거
# - 단어 집합을 각각 8,000개와 2,000개로 줄인 상태에서 정수 시퀀스로 변환했기 때문에 빈도수가 낮은 단어들로만 이루어졌던 샘플 문장의 경우에는 정수 시퀀스 변환 이후에 스페셜 토큰(<SOS> 또는 <EOS> 토큰)만 남아있게 될 수 있음.
# - 따라서, 스페셜 토큰만 남아있어서 길이가 1인 샘플은 제거

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 1278
# 삭제할 테스트 데이터의 개수 : 325
# 훈련 데이터의 개수 : 51377
# 훈련 레이블의 개수 : 51377
# 테스트 데이터의 개수 : 12838
# 테스트 레이블의 개수 : 12838

# %% [markdown]
# ## 2.10 패딩 처리
# - 데이터의 길이가 모두 동일할 수 있도록 패딩 처리

# %%
# 패딩 처리하기
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')
print('=3')
# Out:
# =3

# %% [markdown]
# # 3. 모델 설계, 훈련, 추론

# %% [markdown]
# ## 3.1 훈련용 모델 설계 및 훈련

# %% [markdown]
# ### 3.1.1 인코더 설계

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm3 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
# [주의] 인코더 내 마지막 LSTM 셀이어서 출력 변수의 이름을 모두 숫자 없는 변수명으로 설정함!
encoder_outputs, state_h, state_c = encoder_lstm3(encoder_output2)

# %% [markdown]
# ### 3.1.2 디코더 설계

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
# [주의] 인코더의 마지막 셀에서 출력한 히든 스테이트, 셀 스테이트 값이 디코더의 초기 스테이트 값으로 사용됨!
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %% [markdown]
# ### 3.1.3 디코더의 출력층 설계

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs)

# %% [markdown]
# ### 3.1.4 기본적인 seq2seq 모델 구조 전체 정의

# %%
# 모델 정의
# 전체 모델 입장에서는 입력으로 encoder_inputs, decoder_inputs 두개가 들어오고,
# 최종 출력으로 decoder_softmax_outputs가 나오는 구조인 것임.
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 50)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 50, 128)   │  1,024,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 50, 256), │    394,240 │ embedding[0][0]   │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 50, 256), │    525,312 │ lstm[0][0]        │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 128) │    256,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 50, 256), │    525,312 │ lstm_1[0][0]      │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    394,240 │ embedding_1[0][0… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None,      │    514,000 │ lstm_3[0][0]      │
# │                     │ 2000)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,633,104 (13.86 MB)
#  Trainable params: 3,633,104 (13.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model

# 모델 구조를 그래프 형식으로 저장
plot_model(model, to_file='./model_graph/seq2seq_base_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 3.1.5 어텐션이 추가된 seq2seq with attention 구조로 모델 수정

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 50)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 50, 128)   │  1,024,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 50, 256), │    394,240 │ embedding[0][0]   │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 50, 256), │    525,312 │ lstm[0][0]        │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 128) │    256,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 50, 256), │    525,312 │ lstm_1[0][0]      │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    394,240 │ embedding_1[0][0… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer     │ (None, None, 256) │        256 │ lstm_3[0][0],     │
# │ (AdditiveAttention) │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_layer        │ (None, None, 512) │          0 │ lstm_3[0][0],     │
# │ (Concatenate)       │                   │            │ attention_layer[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None,      │  1,026,000 │ concat_layer[0][… │
# │                     │ 2000)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,145,360 (15.81 MB)
#  Trainable params: 4,145,360 (15.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model

# 수정된 모델 구조를 그래프 형식으로 다시 저장
plot_model(model, to_file='./model_graph/seq2seq_with_attention_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 3.1.6 모델 훈련하기

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
# learning_rate를 적용하는 경우
# learning_rate = 0.0001    # 학습률 지정
# model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=learning_rate),
#               loss=tf.keras.losses.sparse_categorical_crossentropy,
#               metrics=['accuracy'])   # Summarization 태스크의 경우 평가지표를 어떻게 설정해야할까? (BLEU 점수라는 것을 주로 활용한다고 함)

# 콜백 정의
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True)

model_checkpoint = ModelCheckpoint(
    filepath='./best_model/seq2seq_with_attention_best_model.keras',
    monitor='val_loss',
    save_best_only=True)

BATCH_SIZE = 256
EPOCHS = 50

history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train,
                    validation_data=([encoder_input_test, decoder_input_test], decoder_target_test),
                    batch_size=BATCH_SIZE,
                    callbacks=[early_stopping, model_checkpoint],
                    epochs=EPOCHS)
# Out:
# Epoch 1/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 170s 808ms/step - loss: 3.3202 - val_loss: 2.5507
# Epoch 2/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 197s 785ms/step - loss: 2.5814 - val_loss: 2.4888
# Epoch 3/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 167s 829ms/step - loss: 2.4920 - val_loss: 2.4161
# Epoch 4/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 194s 964ms/step - loss: 2.4372 - val_loss: 2.3506
# Epoch 5/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 201s 995ms/step - loss: 2.3596 - val_loss: 2.3113
# Epoch 6/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 184s 918ms/step - loss: 2.3285 - val_loss: 2.2789
# Epoch 7/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 185s 923ms/step - loss: 2.2889 - val_loss: 2.2505
# Epoch 8/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 177s 880ms/step - loss: 2.2474 - val_loss: 2.2325
# Epoch 9/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 177s 880ms/step - loss: 2.2328 - val_loss: 2.1967
# Epoch 10/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 180s 896ms/step - loss: 2.2018 - val_loss: 2.1691
# Epoch 11/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 184s 917ms/step - loss: 2.1632 - val_loss: 2.1400
# Epoch 12/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 170s 844ms/step - loss: 2.1341 - val_loss: 2.1154
# Epoch 13/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 168s 836ms/step - loss: 2.1005 - val_loss: 2.1014
# Epoch 14/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 171s 851ms/step - loss: 2.0793 - val_loss: 2.0757
# Epoch 15/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 169s 840ms/step - loss: 2.0569 - val_loss: 2.0605
# Epoch 16/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 1426s 7s/step - loss: 2.0452 - val_loss: 2.0427
# Epoch 17/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - loss: 2.0202 - val_loss: 2.0278
# Epoch 18/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 219s 1s/step - loss: 1.9930 - val_loss: 2.0179
# Epoch 19/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 230s 1s/step - loss: 1.9707 - val_loss: 2.0068
# Epoch 20/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 192s 958ms/step - loss: 1.9614 - val_loss: 1.9929
# Epoch 21/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 197s 982ms/step - loss: 1.9316 - val_loss: 1.9834
# Epoch 22/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 176s 874ms/step - loss: 1.9150 - val_loss: 1.9745
# Epoch 23/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 201s 868ms/step - loss: 1.9093 - val_loss: 1.9660
# Epoch 24/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 188s 934ms/step - loss: 1.8859 - val_loss: 1.9610
# Epoch 25/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 196s 902ms/step - loss: 1.8849 - val_loss: 1.9484
# Epoch 26/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 182s 906ms/step - loss: 1.8706 - val_loss: 1.9454
# Epoch 27/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 178s 886ms/step - loss: 1.8451 - val_loss: 1.9407
# Epoch 28/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 179s 890ms/step - loss: 1.8341 - val_loss: 1.9326
# Epoch 29/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 185s 923ms/step - loss: 1.8199 - val_loss: 1.9284
# Epoch 30/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 183s 912ms/step - loss: 1.8133 - val_loss: 1.9210
# Epoch 31/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 188s 934ms/step - loss: 1.7960 - val_loss: 1.9187
# Epoch 32/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 187s 933ms/step - loss: 1.7878 - val_loss: 1.9119
# Epoch 33/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 186s 925ms/step - loss: 1.7709 - val_loss: 1.9106
# Epoch 34/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 181s 902ms/step - loss: 1.7573 - val_loss: 1.9105
# Epoch 35/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 196s 977ms/step - loss: 1.7487 - val_loss: 1.9072
# Epoch 36/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 176s 875ms/step - loss: 1.7344 - val_loss: 1.9092
# Epoch 37/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 174s 865ms/step - loss: 1.7252 - val_loss: 1.9028
# Epoch 38/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 188s 936ms/step - loss: 1.7153 - val_loss: 1.9016
# Epoch 39/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 182s 904ms/step - loss: 1.7075 - val_loss: 1.9008
# Epoch 40/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 173s 860ms/step - loss: 1.6892 - val_loss: 1.9005
# Epoch 41/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 177s 882ms/step - loss: 1.6807 - val_loss: 1.9020
# Epoch 42/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 180s 895ms/step - loss: 1.6747 - val_loss: 1.8983
# Epoch 43/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 186s 926ms/step - loss: 1.6577 - val_loss: 1.8973
# Epoch 44/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 185s 840ms/step - loss: 1.6551 - val_loss: 1.8984
# Epoch 45/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 182s 907ms/step - loss: 1.6373 - val_loss: 1.8998
# Epoch 46/50
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 178s 884ms/step - loss: 1.6311 - val_loss: 1.8989

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# epochs_range = range(len(acc))

plt.figure(figsize=(16, 8))
# plt.subplot(1, 2, 1)
# plt.plot(acc, 'bo-', label='Training Accuracy')     # 대시선
# plt.plot(val_acc, 'ro--', label='Validation Accuracy')
# # plt.plot(epochs_range, acc, 'bo-', label='Training Accuracy')     # 대시선
# # plt.plot(epochs_range, val_acc, 'ro--', label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.ylabel('Accuracy')
# plt.ylim([min(plt.ylim()),1])
# plt.title('Training and Validation Accuracy')
# plt.xlabel('epoch')

# plt.subplot(1, 2, 2)
plt.plot(loss, 'bo-', label='Training Loss')
plt.plot(val_loss, 'ro--', label='Validation Loss')
# plt.plot(epochs_range, loss, 'bo-', label='Training Loss')
# plt.plot(epochs_range, val_loss, 'ro--', label='Validation Loss')
# plt.plot(val_loss, 'ro:', label='Validation Loss')    # 점선
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([1.5,3])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## 3.2 추론 모델 설계하기
# - RNN 기반의 seq2seq 모델의 경우 훈련용 모델과 추론용 모델이 달라야 함.
# - 훈련용 모델의 경우에는, 정답에 해당하는 decoder_inputs를 디코더의 입력으로 넣어줘서 설령 특정 타임스텝에서의 예측이 정답과 다른 경우라 하더라도 decoder_inputs에 포함된 정답이 매 타임스텝마다 새롭게 주어져서 계속 정답과 비교해 가면서 학습이 진행되어질 수 있음.
# - 하지만, 추론용 모델의 경우에는, 정답에 해당하는 decoder_inputs를 디코더의 입력으로 넣어줄 수 없기 때문에 디코더의 매 타입스텝마다 예측한 결과값이(해당 결과값이 맞았든 틀렸든 상관없이) 다음 스텝의 디코더 입력값으로 주어지는 반복형 구조를 가질 수 밖에 없기 때문임.
# - 따라서, 훈련용 모델의 경우 인코더와 디코더가 통합된 모델 하나로 정의할 수 있었지만, 추론용 모델의 경우에는 인코더와 디코더를 아예 분리해서 정의해 사용해야 함!

# %% [markdown]
# ### 3.2.1 추론 단계(테스트 단계)에서 사용할 사전 미리 준비

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %% [markdown]
# ### 3.2.2 추론용 인코더 설계

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %% [markdown]
# ### 3.2.3 추론용 디코더 설계

# %%
# 바로 직전 타임스텝의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))   # 히든 스테이트용
decoder_state_input_c = Input(shape=(hidden_size,))   # 셀 스테이트용

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
# [참고] LMS의 원래 코드에서는 그냥 state_h2, state_c2 라고만 되어 있었는데, 앞에서 사용한 인코더 내 두 번째 LSTM의 출력값인 state_h2, state_c2와 구분하기 위해 변수명 앞에 dec_ 를 붙여 줌.
decoder_outputs2, dec_state_h2, dec_state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat)

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c],
    # [참고] 여기에서도 LMS의 원래 코드에서는 그냥 state_h2, state_c2 였는데, 앞에서 변경한 변수명과 일치시키기 위해 변수명 앞에 dec_ 를 붙여줌.
    [decoder_outputs2] + [dec_state_h2, dec_state_c2])

# %% [markdown]
# ### 3.2.4 모델 추론하기(테스트하기)

# %% [markdown]
# #### 3.2.4.1 추론용 단어 시퀀스 완성 함수 정의

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# #### 3.2.4.2 정수 시퀀스를 텍스트 시퀀스로 변환하는 함수 정의(원문용, 요약문용)

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + tar_index_to_word[i]+' '
    return temp

# %% [markdown]
# #### 3.2.4.3 추론하기(테스트하기)

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : markers great smoothly write fondant gum paste even chocolate arrived time reason get stars need cleaned often working chocolate tip chocolate bit write left without cleaning write great details cake pops work wonderfully candy melts
# 실제 요약 : sostoken great
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 예측 요약 :  great product
#
#
# 원문 : glad found product husband loves cornbread selling corn meal nothing flour produce cornbread satisfied adding yellow corn grits recipe happy cornbread
# 실제 요약 : sostoken husband
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  great taste
#
#
# 원문 : excellent product iced tea need make bigger bags making large quantities iced tea like opening bags make tea
# 실제 요약 : sostoken excellent for iced tea
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great tea
#
#
# 원문 : cook lot local store stopped carrying product use anything bbq anything mexican cannot recommend enough flavors great stuff
# 실제 요약 : sostoken seasoning
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  great
#
#
# 원문 : crackers called recipe bake cake ordered amazon reviews stated crackers arrived broken would purposes however arrived intact shipping issues whatsoever use crackers cake enjoying cracker good cake fabulous
# 실제 요약 : sostoken made great cake
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  great crackers
#
#
# 원문 : previously used lavender oil sorry bought brand much thinner anything else used
# 실제 요약 : sostoken much than expected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  good product
#
#
# 원문 : food worked great two dogs year ago something changed food caused dogs severe diarrhea food caused problems return switched different brand
# 실제 요약 : sostoken something changed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 예측 요약 :  great food
#
#
# 원문 : love make sun tea tea bags nice hot day sit chilled glass tasty sweet highly recommended
# 실제 요약 : sostoken super tasty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 예측 요약 :  great tea
#
#
# 원문 : equipment making turkish coffee worth trying wonderfully smooth light taste greek coffee tried liked dark variety
# 실제 요약 : sostoken good greek coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : soak black beans overnight use pressure cooker cook poor results brand time time beans overcooked mushy others crunchy tried different soaking times different cooking pressure cooker always end beans evenly cooked brands cook fine thing think issue particular brand
# 실제 요약 : sostoken texture after cooking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 예측 요약 :  good product
#
#
# 원문 : drink lot stuff folgers classic choice use flavors instant thick glue sell starbucks prefer prefer thing serve machine shop nobody go thru lot stuff must like
# 실제 요약 : sostoken my choice in coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  not fan
#
#
# 원문 : favorite granola bar vegan gluten free difficult comes finding granola bars meet needs one absolutely delicious love ingredients strawberries throughout whole bar highly recommend
# 실제 요약 : sostoken my favorite
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  delicious
#
#
# 원문 : absolutely die get looking cooked lard salt absolutely best chip world ultimate test eat one one possible finish bag
# 실제 요약 : sostoken worst in the world love these
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 예측 요약 :  great snack
#
#
# 원문 : pasta far favorite brand tried others one delicious taste regular pasta anymore gotten whole family eat love highly recommend
# 실제 요약 : sostoken best rice pasta
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  best gluten free pasta
#
#
# 원문 : mother three early thinking heading gym sometimes started using sport shots saw works outs energy levels general feeling really morning help clear head also provide great energy without feeling jitters never feel like crash also love natural cannot get enough
# 실제 요약 : sostoken are awesome
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  great product
#
#
# 원문 : ordered best friend loved perfect size wall nice starter bonsai good quality ordered another one match
# 실제 요약 : sostoken perfect
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  great product
#
#
# 원문 : really like selection choice three different hot cocoa chocolates favorite mint chocolate tastes like mint chocolate aroma hot mint chocolate milk chocolate dark chocolate equally flavorful well price amazon reasonable
# 실제 요약 : sostoken nice flavor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  chocolate
#
#
# 원문 : gluten trying wean dairy well larabar pecan pie gluten dairy actually tastes great bars ounces find right size snack pecan flavor sweet sweet bar nice balance soft crunchy calories bar fat calories far healthier candy bar ingredients dates pecans almonds amazingly simple highly recommended
# 실제 요약 : sostoken yum
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  delicious
#
#
# 원문 : first time ever brand expected hard soft chewy gummy bears used
# 실제 요약 : sostoken hard not chewy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 예측 요약 :  good
#
#
# 원문 : great tasting snack full things healthy little pricey obviously expensive pint ice cream one best online around well order confidence quick shipping great prices selection
# 실제 요약 : sostoken healthy tastes great
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great snack
#
#
# 원문 : nuts exception lightly covered onion garlic mauna loa good
# 실제 요약 : sostoken always good
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 예측 요약 :  delicious
#
#
# 원문 : slightly calories packed fruit whole grains makes great breakfast little time son hubby like eating quickly morning work easy eat yummy make little mess thing would make love better organic
# 실제 요약 : sostoken perfect for fast breakfast
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 예측 요약 :  great for the family
#
#
# 원문 : value buying bulk better however taking want individual packaging sure get lb home want fill bunch small bags hemp seed try getting airport use travel get home
# 실제 요약 : sostoken great for travel
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great product
#
#
# 원문 : great idea fruit juice wife enjoyed watermelon strawberry version better though seem aftertaste slight heaviness kiwi berry nonetheless quite good
# 실제 요약 : sostoken but aftertaste
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 예측 요약 :  good but not great
#
#
# 원문 : great kid allowance money able ride bike local white chicago area great find one comment appears stored hot area suckers seem melted formed
# 실제 요약 : sostoken childhood memories
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  great taste
#
#
# 원문 : bought product boyfriend christmas local drugstore absolutely love scent buy bottle expensive get sweet deal delivery came days actual arrival date strange nothing damaged thats good great service even better scent highly recommended
# 실제 요약 : sostoken love it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  great product
#
#
# 원문 : incredibly picky dogs love treats pieces nice small reccommend even finicky dogs dogs digestive issues
# 실제 요약 : sostoken my dogs for more
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 예측 요약 :  great for training
#
#
# 원문 : love product works well keeping hydrated training runs stomach count help things little hydrate even attest treating hangover highly recommend quick shipping good price vendor
# 실제 요약 : sostoken this stuff rocks
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  my dog loves these
#
#
# 원문 : nd cup brewer one awesome coffee tea cup size choice hot cocoa easy use makes great cup every time little effort could want pleased usual keurig products extremely durable reliable fast buy brewer wont need another many years come
# 실제 요약 : sostoken best home office brewer for the money
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : good snack easy bring along great container love screw lid however pepper taste quite strong warned easily get upset stomach deal heartburn snack eat time however also usually need salt craving pm would probably buy
# 실제 요약 : good snack but bit hard on the tummy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  great taste
#
#
# 원문 : always easy find cereals kids adults enjoy equally kashi cinnamon harvest fits bill house right amount sweetness nice cinnamon bite youngest daughter loves without milk snack perfect finger food glad amazon offers subscription one drawback little pricey worth
# 실제 요약 : sostoken my whole family loves it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 예측 요약 :  great cereal
#
#
# 원문 : confirmed anywhere plastic non bpa able find info yet thanks
# 실제 요약 : sostoken what kind of plastic
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 예측 요약 :  no
#
#
# 원문 : chip addict far tastiest non homemade chips ever plus healthy problem cannot decide flavor favorite
# 실제 요약 : sostoken yum
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 예측 요약 :  great chips
#
#
# 원문 : keurig best favorite coffee van houtte french roast great tasting coffee nice full flavour without crazy strong started using keurig office bought one home came home brewer years later single cup brewer satisfied convenience use quality coffee brewed enjoy van houtte line especially french roast
# 실제 요약 : sostoken superb coffee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : chai tea delicious flavor bad thing dissolve completely matter hot water much stir makes last sips bit gritty
# 실제 요약 : sostoken great chai
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  great tea
#
#
# 원문 : dogs really like say looks much better old brown look dog food little pricey work larger dogs eat lot medium sized dogs seems like winner
# 실제 요약 : very good looking and the dogs like it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 예측 요약 :  great for dogs
#
#
# 원문 : year old loves first time ate one picnic would forgotten bring spoon held lips thinking could sucking needed finished pouch one minute would highly recommend easy parents
# 실제 요약 : sostoken delicious
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  great for kids
#
#
# 원문 : cereal packs punch tremendous amount fiber yet tastes like delicious regular cereal year old boys love
# 실제 요약 : sostoken yummy and good for you
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great cereal
#
#
# 원문 : love texture flavor product strong easily break put lot food
# 실제 요약 : sostoken tasty but easily
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 예측 요약 :  great taste
#
#
# 원문 : stumbled product years ago got tired paying grocery store prices real vanilla product blend real vanilla tastes great saves us bundle especially pack going last us years recommend highly
# 실제 요약 : sostoken excellent have been using it for years
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 예측 요약 :  great product
#
#
# 원문 : got last night excited wanted make crystals first boiled water stove created goo substance pretty fun work needed entertaining hot water stove much better excited see crystals get stuff thank
# 실제 요약 : sostoken bought this to make
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  good but not great
#
#
# 원문 : eat gluten free tried almost every type bar available pleasantly surprised got try bar moist delicious tasted like blueberry lemon cookie big blueberries cannot wait try flavors thanks pamela making another great tasting product
# 실제 요약 : sostoken thank goodness
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 예측 요약 :  great gluten free cookie
#
#
# 원문 : expecting little tree pot bag rocks page instructions dollars gone another route
# 실제 요약 : sostoken not much to it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 예측 요약 :  great product
#
#
# 원문 : dairy allergy severe lactose intolerance feel left chocolate bars help upset stomach also aid keep weight delicious
# 실제 요약 : sostoken enjoy life dark bars
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 예측 요약 :  great for kids
#
#
# 원문 : added ingrediants actually pretty good little soupy even though rice already
# 실제 요약 : sostoken almost complete
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  baby food
#
#
# 원문 : husband first coffee work wanted try tasty order
# 실제 요약 : sostoken yum
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  good coffee
#
#
# 원문 : live new england like people region hooked dunkin donuts coffee brand tastes like dunkin brand sells area definately favorite
# 실제 요약 : sostoken tastes just like
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 예측 요약 :  great coffee
#
#
# 원문 : ordered another website newly diagnosed need gluten free year old son loved returning site longer find returned old friend amazon com impressed gf products get even excited use subscribe save option supply mac cheese always house thanks
# 실제 요약 : sostoken tastes like the real thing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 예측 요약 :  great gluten free
#
#
# 원문 : product arrived expected tempted order types cat food reviews say get thought ordering cats like beef shreds also reviews said got pate want take chance nice get varieties one case rather going box store check liked got
# 실제 요약 : sostoken the cats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 예측 요약 :  my cats love it
#
#
# 원문 : best bloody mary mix tried sure hit first pour
# 실제 요약 : sostoken delicious
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 예측 요약 :  great

# %% [markdown]
# # 4. summa를 활용한 추출적 요약

# %%
import requests
from summa.summarizer import summarize

# %%
# 매트릭스 시놉시스 다운로드
text = requests.get('http://rare-technologies.com/the_matrix_synopsis.txt').text

# %%
# 일부만 출력해 보기
print(text[:1500])
# Out:
# The screen is filled with green, cascading code which gives way to the title, The Matrix.
#
# A phone rings and text appears on the screen: "Call trans opt: received. 2-19-98 13:24:18 REC: Log>" As a conversation takes place between Trinity (Carrie-Anne Moss) and Cypher (Joe Pantoliano), two free humans, a table of random green numbers are being scanned and individual numbers selected, creating a series of digits not unlike an ordinary phone number, as if a code is being deciphered or a call is being traced.
#
# Trinity discusses some unknown person. Cypher taunts Trinity, suggesting she enjoys watching him. Trinity counters that "Morpheus (Laurence Fishburne) says he may be 'the One'," just as the sound of a number being selected alerts Trinity that someone may be tracing their call. She ends the call.
#
# Armed policemen move down a darkened, decrepit hallway in the Heart O' the City Hotel, their flashlight beam bouncing just ahead of them. They come to room 303, kick down the door and find a woman dressed in black, facing away from them. It's Trinity. She brings her hands up from the laptop she's working on at their command.
#
# Outside the hotel a car drives up and three agents appear in neatly pressed black suits. They are Agent Smith (Hugo Weaving), Agent Brown (Paul Goddard), and Agent Jones (Robert Taylor). Agent Smith and the presiding police lieutenant argue. Agent Smith admonishes the policeman that they were given specific orders to contact the agents first, for their

# %%
# summa의 summarize 함수 파라미터 설명
"""
text (str) : 요약할 테스트.
ratio (float, optional) – 요약문에서 원본에서 선택되는 문장 비율. 0~1 사이값
words (int or None, optional) – 출력에 포함할 단어 수.
만약, ratio와 함께 두 파라미터가 모두 제공되는 경우 ratio는 무시한다.
split (bool, optional) – True면 문장 list / False는 조인(join)된 문자열을 반환
"""
print('Summary:')
print(summarize(text, ratio=0.005))
# Out:
# Summary:
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %%
# 결과를 리스트로 받기
print('Summary:')
print(summarize(text, ratio=0.005, split=True))
# Out:
# Summary:
# ['Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.', 'Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.']

# %%
# 단어의 수로 요약문 크기 조절하기
print('Summary:')
print(summarize(text, words=50))
# Out:
# Summary:
# Trinity takes Neo to Morpheus.
# Morpheus, Trinity, Neo, Apoc, Switch, Mouse and Cypher are jacked into the Matrix.
# Trinity brings the helicopter down to the floor that Morpheus is on and Neo opens fire on the three Agents.

# %% [markdown]
# # 5. 참고자료

# %% [markdown]
# ## 5.1 Tokenizer 객체의 주요 프로퍼티

# %%
src_tokenizer.word_index    # 딕셔너리 타입 {'단어': 인덱스 번호}
# Out:
# {'like': 1,
#  'good': 2,
#  'great': 3,
#  'taste': 4,
#  'product': 5,
#  'love': 6,
#  'one': 7,
#  'coffee': 8,
#  'flavor': 9,
#  'would': 10,
#  'tea': 11,
#  'really': 12,
#  'get': 13,
#  'amazon': 14,
#  'best': 15,
#  'price': 16,
#  'buy': 17,
#  'much': 18,
#  'food': 19,
#  'time': 20,
#  'find': 21,
#  'use': 22,
#  'little': 23,
#  'tried': 24,
#  'better': 25,
#  'well': 26,
#  'also': 27,
#  'make': 28,
#  'chocolate': 29,
#  'try': 30,
#  'dog': 31,
#  'eat': 32,
#  'even': 33,
#  'bought': 34,
#  'sweet': 35,
#  'delicious': 36,
#  'found': 37,
#  'order': 38,
#  'could': 39,
#  'drink': 40,
#  'cup': 41,
#  'recommend': 42,
#  'tastes': 43,
#  'loves': 44,
#  'used': 45,
#  'bag': 46,
#  'sugar': 47,
#  'favorite': 48,
#  'store': 49,
#  'cannot': 50,
#  'first': 51,
#  'free': 52,
#  'nice': 53,
#  'way': 54,
#  'made': 55,
#  'go': 56,
#  'box': 57,
#  'perfect': 58,
#  'got': 59,
#  'day': 60,
#  'bit': 61,
#  'mix': 62,
#  'since': 63,
#  'think': 64,
#  'easy': 65,
#  'dogs': 66,
#  'water': 67,
#  'ordered': 68,
#  'snack': 69,
#  'ever': 70,
#  'give': 71,
#  'two': 72,
#  'hot': 73,
#  'many': 74,
#  'flavors': 75,
#  'every': 76,
#  'still': 77,
#  'never': 78,
#  'makes': 79,
#  'treats': 80,
#  'stuff': 81,
#  'always': 82,
#  'healthy': 83,
#  'without': 84,
#  'know': 85,
#  'brand': 86,
#  'right': 87,
#  'quality': 88,
#  'fresh': 89,
#  'want': 90,
#  'tasty': 91,
#  'definitely': 92,
#  'hard': 93,
#  'years': 94,
#  'keep': 95,
#  'strong': 96,
#  'something': 97,
#  'lot': 98,
#  'add': 99,
#  'buying': 100,
#  'enjoy': 101,
#  'wonderful': 102,
#  'small': 103,
#  'happy': 104,
#  'treat': 105,
#  'enough': 106,
#  'milk': 107,
#  'old': 108,
#  'bad': 109,
#  'excellent': 110,
#  'less': 111,
#  'local': 112,
#  'say': 113,
#  'chips': 114,
#  'highly': 115,
#  'different': 116,
#  'organic': 117,
#  'however': 118,
#  'purchase': 119,
#  'shipping': 120,
#  'need': 121,
#  'eating': 122,
#  'sure': 123,
#  'regular': 124,
#  'far': 125,
#  'size': 126,
#  'long': 127,
#  'looking': 128,
#  'products': 129,
#  'tasting': 130,
#  'put': 131,
#  'thought': 132,
#  'stores': 133,
#  'pack': 134,
#  'tasted': 135,
#  'back': 136,
#  'salt': 137,
#  'using': 138,
#  'though': 139,
#  'pretty': 140,
#  'whole': 141,
#  'purchased': 142,
#  'bags': 143,
#  'loved': 144,
#  'cups': 145,
#  'work': 146,
#  'bars': 147,
#  'worth': 148,
#  'cookies': 149,
#  'high': 150,
#  'texture': 151,
#  'gluten': 152,
#  'package': 153,
#  'low': 154,
#  'ingredients': 155,
#  'grocery': 156,
#  'green': 157,
#  'family': 158,
#  'thing': 159,
#  'sauce': 160,
#  'arrived': 161,
#  'big': 162,
#  'quite': 163,
#  'popcorn': 164,
#  'going': 165,
#  'rice': 166,
#  'last': 167,
#  'received': 168,
#  'year': 169,
#  'take': 170,
#  'expensive': 171,
#  'came': 172,
#  'candy': 173,
#  'actually': 174,
#  'anything': 175,
#  'real': 176,
#  'item': 177,
#  'feel': 178,
#  'cat': 179,
#  'cereal': 180,
#  'oil': 181,
#  'almost': 182,
#  'see': 183,
#  'calories': 184,
#  'dark': 185,
#  'natural': 186,
#  'husband': 187,
#  'chicken': 188,
#  'full': 189,
#  'money': 190,
#  'another': 191,
#  'new': 192,
#  'blend': 193,
#  'butter': 194,
#  'trying': 195,
#  'bar': 196,
#  'around': 197,
#  'kids': 198,
#  'smell': 199,
#  'morning': 200,
#  'getting': 201,
#  'disappointed': 202,
#  'people': 203,
#  'brands': 204,
#  'fruit': 205,
#  'amount': 206,
#  'coconut': 207,
#  'absolutely': 208,
#  'several': 209,
#  'home': 210,
#  'half': 211,
#  'away': 212,
#  'cheese': 213,
#  'diet': 214,
#  'bitter': 215,
#  'fast': 216,
#  'able': 217,
#  'added': 218,
#  'wish': 219,
#  'usually': 220,
#  'dry': 221,
#  'smooth': 222,
#  'ones': 223,
#  'available': 224,
#  'oz': 225,
#  'light': 226,
#  'us': 227,
#  'deal': 228,
#  'kind': 229,
#  'nothing': 230,
#  'works': 231,
#  'foods': 232,
#  'fat': 233,
#  'liked': 234,
#  'may': 235,
#  'breakfast': 236,
#  'come': 237,
#  'flavored': 238,
#  'ordering': 239,
#  'days': 240,
#  'probably': 241,
#  'company': 242,
#  'per': 243,
#  'problem': 244,
#  'cats': 245,
#  'case': 246,
#  'quick': 247,
#  'cheaper': 248,
#  'making': 249,
#  'save': 250,
#  'months': 251,
#  'black': 252,
#  'things': 253,
#  'said': 254,
#  'fine': 255,
#  'quickly': 256,
#  'boxes': 257,
#  'bread': 258,
#  'gift': 259,
#  'reviews': 260,
#  'peanut': 261,
#  'pasta': 262,
#  'glad': 263,
#  'seems': 264,
#  'variety': 265,
#  'large': 266,
#  'bottle': 267,
#  'honey': 268,
#  'especially': 269,
#  'recommended': 270,
#  'son': 271,
#  'packaging': 272,
#  'comes': 273,
#  'house': 274,
#  'rich': 275,
#  'juice': 276,
#  'others': 277,
#  'gave': 278,
#  'look': 279,
#  'prefer': 280,
#  'protein': 281,
#  'drinking': 282,
#  'instead': 283,
#  'three': 284,
#  'spicy': 285,
#  'anyone': 286,
#  'thank': 287,
#  'daughter': 288,
#  'syrup': 289,
#  'cream': 290,
#  'amazing': 291,
#  'top': 292,
#  'thanks': 293,
#  'roast': 294,
#  'yummy': 295,
#  'everyone': 296,
#  'energy': 297,
#  'stars': 298,
#  'meal': 299,
#  'white': 300,
#  'soft': 301,
#  'wanted': 302,
#  'cans': 303,
#  'likes': 304,
#  'times': 305,
#  'teeth': 306,
#  'vanilla': 307,
#  'might': 308,
#  'seem': 309,
#  'must': 310,
#  'fan': 311,
#  'month': 312,
#  'extra': 313,
#  'maybe': 314,
#  'next': 315,
#  'ginger': 316,
#  'fact': 317,
#  'either': 318,
#  'health': 319,
#  'pieces': 320,
#  'else': 321,
#  'plus': 322,
#  'awesome': 323,
#  'everything': 324,
#  'enjoyed': 325,
#  'value': 326,
#  'salty': 327,
#  'baby': 328,
#  'teas': 329,
#  'friends': 330,
#  'crunchy': 331,
#  'cost': 332,
#  'nuts': 333,
#  'bold': 334,
#  'keurig': 335,
#  'least': 336,
#  'beans': 337,
#  'super': 338,
#  'couple': 339,
#  'longer': 340,
#  'went': 341,
#  'yet': 342,
#  'market': 343,
#  'online': 344,
#  'open': 345,
#  'ice': 346,
#  'ago': 347,
#  'plastic': 348,
#  'started': 349,
#  'soup': 350,
#  'decided': 351,
#  'chew': 352,
#  'took': 353,
#  'help': 354,
#  'pleased': 355,
#  'noodles': 356,
#  'although': 357,
#  'cold': 358,
#  'mouth': 359,
#  'ok': 360,
#  'corn': 361,
#  'alternative': 362,
#  'pepper': 363,
#  'second': 364,
#  'minutes': 365,
#  'week': 366,
#  'expected': 367,
#  'review': 368,
#  'flavorful': 369,
#  'service': 370,
#  'lemon': 371,
#  'says': 372,
#  'jerky': 373,
#  'read': 374,
#  'delivery': 375,
#  'snacks': 376,
#  'cookie': 377,
#  'cocoa': 378,
#  'let': 379,
#  'drinks': 380,
#  'type': 381,
#  'plain': 382,
#  'soda': 383,
#  'rather': 384,
#  'wife': 385,
#  'ounce': 386,
#  'crackers': 387,
#  'weight': 388,
#  'wheat': 389,
#  'exactly': 390,
#  'machine': 391,
#  'goes': 392,
#  'powder': 393,
#  'gets': 394,
#  'beef': 395,
#  'cook': 396,
#  'aroma': 397,
#  'surprised': 398,
#  'decaf': 399,
#  'french': 400,
#  'side': 401,
#  'special': 402,
#  'cooking': 403,
#  'problems': 404,
#  'sometimes': 405,
#  'version': 406,
#  'meat': 407,
#  'mixed': 408,
#  'opened': 409,
#  'smaller': 410,
#  'packaged': 411,
#  'convenient': 412,
#  'red': 413,
#  'easily': 414,
#  'guess': 415,
#  'friend': 416,
#  'wrong': 417,
#  'choice': 418,
#  'part': 419,
#  'aftertaste': 420,
#  'refreshing': 421,
#  'shipped': 422,
#  'picky': 423,
#  'clean': 424,
#  'tell': 425,
#  'fantastic': 426,
#  'believe': 427,
#  'serving': 428,
#  'place': 429,
#  'dried': 430,
#  'care': 431,
#  'brown': 432,
#  'difference': 433,
#  'artificial': 434,
#  'orange': 435,
#  'cinnamon': 436,
#  'subscribe': 437,
#  'cake': 438,
#  'hand': 439,
#  'oatmeal': 440,
#  'mild': 441,
#  'smells': 442,
#  'giving': 443,
#  'packs': 444,
#  'christmas': 445,
#  'left': 446,
#  'container': 447,
#  'lots': 448,
#  'slightly': 449,
#  'reason': 450,
#  'potato': 451,
#  'live': 452,
#  'often': 453,
#  'brew': 454,
#  'huge': 455,
#  'seeds': 456,
#  'recently': 457,
#  'bite': 458,
#  'chewy': 459,
#  'recipe': 460,
#  'spice': 461,
#  'etc': 462,
#  'continue': 463,
#  'line': 464,
#  'bottles': 465,
#  'run': 466,
#  'stomach': 467,
#  'bulk': 468,
#  'sent': 469,
#  'coffees': 470,
#  'looks': 471,
#  'fiber': 472,
#  'almonds': 473,
#  'cherry': 474,
#  'pop': 475,
#  'pay': 476,
#  'looked': 477,
#  'cut': 478,
#  'dinner': 479,
#  'gives': 480,
#  'seller': 481,
#  'needed': 482,
#  'iced': 483,
#  'end': 484,
#  'life': 485,
#  'delivered': 486,
#  'simply': 487,
#  'chai': 488,
#  'compared': 489,
#  'carry': 490,
#  'excited': 491,
#  'stick': 492,
#  'overall': 493,
#  'starbucks': 494,
#  'filling': 495,
#  'packages': 496,
#  'eaten': 497,
#  'past': 498,
#  'original': 499,
#  'start': 500,
#  'calorie': 501,
#  'toy': 502,
#  'apple': 503,
#  'ate': 504,
#  'hope': 505,
#  'helps': 506,
#  'date': 507,
#  'waste': 508,
#  'unfortunately': 509,
#  'weeks': 510,
#  'close': 511,
#  'takes': 512,
#  'com': 513,
#  'night': 514,
#  'lunch': 515,
#  'gum': 516,
#  'items': 517,
#  'chip': 518,
#  'heat': 519,
#  'granola': 520,
#  'purchasing': 521,
#  'keeps': 522,
#  'weak': 523,
#  'larger': 524,
#  'creamy': 525,
#  'saw': 526,
#  'jar': 527,
#  'healthier': 528,
#  'canned': 529,
#  'needs': 530,
#  'someone': 531,
#  'soon': 532,
#  'color': 533,
#  'soy': 534,
#  'wait': 535,
#  'idea': 536,
#  'feed': 537,
#  'course': 538,
#  'gone': 539,
#  'packed': 540,
#  'olive': 541,
#  'single': 542,
#  'similar': 543,
#  'broken': 544,
#  'along': 545,
#  'sold': 546,
#  'already': 547,
#  'stale': 548,
#  'four': 549,
#  'extremely': 550,
#  'pumpkin': 551,
#  'sweetness': 552,
#  'seasoning': 553,
#  'stock': 554,
#  'nut': 555,
#  'caffeine': 556,
#  'condition': 557,
#  'change': 558,
#  'salad': 559,
#  'crunch': 560,
#  'finally': 561,
#  'hours': 562,
#  'microwave': 563,
#  'consistency': 564,
#  'expect': 565,
#  'please': 566,
#  'given': 567,
#  'anywhere': 568,
#  'inside': 569,
#  'fish': 570,
#  'beat': 571,
#  'pet': 572,
#  'hooked': 573,
#  'non': 574,
#  'daily': 575,
#  'mine': 576,
#  'star': 577,
#  'pound': 578,
#  'espresso': 579,
#  'medium': 580,
#  'experience': 581,
#  'baking': 582,
#  'stop': 583,
#  'shipment': 584,
#  'locally': 585,
#  'flour': 586,
#  'together': 587,
#  'maker': 588,
#  'cheap': 589,
#  'training': 590,
#  'hair': 591,
#  'within': 592,
#  'leave': 593,
#  'certainly': 594,
#  'packets': 595,
#  'eats': 596,
#  'lb': 597,
#  'pork': 598,
#  'yogurt': 599,
#  'stopped': 600,
#  'totally': 601,
#  'greenies': 602,
#  'anymore': 603,
#  'reasonable': 604,
#  'difficult': 605,
#  'future': 606,
#  'rest': 607,
#  'thick': 608,
#  'banana': 609,
#  'sour': 610,
#  'due': 611,
#  'chews': 612,
#  'adding': 613,
#  'instant': 614,
#  'almond': 615,
#  'yum': 616,
#  'worked': 617,
#  'list': 618,
#  'formula': 619,
#  'vet': 620,
#  'area': 621,
#  'hit': 622,
#  'name': 623,
#  'bowl': 624,
#  'puppy': 625,
#  'satisfying': 626,
#  'break': 627,
#  'perfectly': 628,
#  'easier': 629,
#  'chili': 630,
#  'kick': 631,
#  'combination': 632,
#  'licorice': 633,
#  'opinion': 634,
#  'based': 635,
#  'ground': 636,
#  'completely': 637,
#  'done': 638,
#  'wow': 639,
#  'sale': 640,
#  'sodium': 641,
#  'bland': 642,
#  'moist': 643,
#  'fun': 644,
#  'pure': 645,
#  'shop': 646,
#  'throw': 647,
#  'substitute': 648,
#  'sell': 649,
#  'true': 650,
#  'crazy': 651,
#  'mind': 652,
#  'baked': 653,
#  'carb': 654,
#  'leaves': 655,
#  'world': 656,
#  'spices': 657,
#  'finding': 658,
#  'count': 659,
#  'satisfied': 660,
#  'recipes': 661,
#  'pot': 662,
#  'raw': 663,
#  'stay': 664,
#  'ingredient': 665,
#  'decent': 666,
#  'truly': 667,
#  'today': 668,
#  'pricey': 669,
#  'finish': 670,
#  'hoping': 671,
#  'horrible': 672,
#  'seemed': 673,
#  'okay': 674,
#  'mint': 675,
#  'addition': 676,
#  'five': 677,
#  'grain': 678,
#  'lower': 679,
#  'become': 680,
#  'pick': 681,
#  'costco': 682,
#  'blue': 683,
#  'summer': 684,
#  'mixes': 685,
#  'dish': 686,
#  'option': 687,
#  'simple': 688,
#  'twice': 689,
#  'bottom': 690,
#  'contains': 691,
#  'batch': 692,
#  'tiny': 693,
#  'none': 694,
#  'expecting': 695,
#  'mess': 696,
#  'hint': 697,
#  'yes': 698,
#  'favorites': 699,
#  'piece': 700,
#  'told': 701,
#  'entire': 702,
#  'newman': 703,
#  'thin': 704,
#  'normally': 705,
#  'grey': 706,
#  'customer': 707,
#  'content': 708,
#  'maple': 709,
#  'cooked': 710,
#  'mom': 711,
#  'later': 712,
#  'priced': 713,
#  'hour': 714,
#  'packet': 715,
#  'forward': 716,
#  'discovered': 717,
#  'particular': 718,
#  'veggies': 719,
#  'plan': 720,
#  'pleasant': 721,
#  'description': 722,
#  'noticed': 723,
#  'strawberry': 724,
#  'glass': 725,
#  'body': 726,
#  'six': 727,
#  'drinker': 728,
#  'impressed': 729,
#  'terrible': 730,
#  'remember': 731,
#  'sweetener': 732,
#  'adds': 733,
#  'pancakes': 734,
#  'acid': 735,
#  'varieties': 736,
#  'awful': 737,
#  'pie': 738,
#  'loose': 739,
#  'warm': 740,
#  'dont': 741,
#  'normal': 742,
#  'serve': 743,
#  'unless': 744,
#  'seen': 745,
#  'turned': 746,
#  'door': 747,
#  'issues': 748,
#  'bones': 749,
#  'candies': 750,
#  'supermarket': 751,
#  'prices': 752,
#  'label': 753,
#  'switch': 754,
#  'return': 755,
#  'otherwise': 756,
#  'everyday': 757,
#  'paid': 758,
#  'stronger': 759,
#  'called': 760,
#  'chocolates': 761,
#  'anyway': 762,
#  'job': 763,
#  'oh': 764,
#  'salmon': 765,
#  'earl': 766,
#  'italian': 767,
#  'roasted': 768,
#  'office': 769,
#  'garlic': 770,
#  'bears': 771,
#  'ready': 772,
#  'individual': 773,
#  'pods': 774,
#  'skin': 775,
#  'caramel': 776,
#  'subscription': 777,
#  'fit': 778,
#  'shake': 779,
#  'bean': 780,
#  'agree': 781,
#  'immediately': 782,
#  'uses': 783,
#  'felt': 784,
#  'thinking': 785,
#  'mountain': 786,
#  'shape': 787,
#  'stevia': 788,
#  'beverage': 789,
#  'bring': 790,
#  'carrying': 791,
#  'style': 792,
#  'meals': 793,
#  'heavy': 794,
#  'flavoring': 795,
#  'taking': 796,
#  'ask': 797,
#  'contain': 798,
#  'homemade': 799,
#  'overly': 800,
#  'feeling': 801,
#  'ship': 802,
#  'unlike': 803,
#  'vinegar': 804,
#  'convenience': 805,
#  'somewhat': 806,
#  'thrilled': 807,
#  'party': 808,
#  'allergies': 809,
#  'feeding': 810,
#  'complaint': 811,
#  'check': 812,
#  'matter': 813,
#  'nicely': 814,
#  'touch': 815,
#  'results': 816,
#  'peanuts': 817,
#  'liquid': 818,
#  'crisp': 819,
#  'breath': 820,
#  'chewing': 821,
#  'benefits': 822,
#  'changed': 823,
#  'nearly': 824,
#  'carbs': 825,
#  'sealed': 826,
#  'hands': 827,
#  'worst': 828,
#  'except': 829,
#  'person': 830,
#  'point': 831,
#  'pouch': 832,
#  'overpowering': 833,
#  'supply': 834,
#  'wrapped': 835,
#  'lime': 836,
#  'sticks': 837,
#  'afternoon': 838,
#  'plenty': 839,
#  'reading': 840,
#  'set': 841,
#  'sorry': 842,
#  'sick': 843,
#  'send': 844,
#  'sea': 845,
#  'trouble': 846,
#  'call': 847,
#  'mother': 848,
#  'bigger': 849,
#  'mostly': 850,
#  'usual': 851,
#  'raspberry': 852,
#  'grams': 853,
#  'bbq': 854,
#  'eggs': 855,
#  'source': 856,
#  'supposed': 857,
#  'craving': 858,
#  'bake': 859,
#  'near': 860,
#  'fairly': 861,
#  'crispy': 862,
#  'nutrition': 863,
#  'mango': 864,
#  'prepare': 865,
#  'kinds': 866,
#  'expiration': 867,
#  'gf': 868,
#  'perhaps': 869,
#  'balance': 870,
#  'short': 871,
#  'berry': 872,
#  'dented': 873,
#  'gummy': 874,
#  'kitchen': 875,
#  'stuck': 876,
#  'running': 877,
#  'picture': 878,
#  'weird': 879,
#  'biscuits': 880,
#  'means': 881,
#  'served': 882,
#  'pizza': 883,
#  'walmart': 884,
#  'dishes': 885,
#  'higher': 886,
#  'hate': 887,
#  'jelly': 888,
#  'alot': 889,
#  'addicted': 890,
#  'china': 891,
#  'kid': 892,
#  'children': 893,
#  'brought': 894,
#  'ended': 895,
#  'sample': 896,
#  'working': 897,
#  'plant': 898,
#  'kept': 899,
#  'share': 900,
#  'pleasantly': 901,
#  'coming': 902,
#  'enjoys': 903,
#  'whatever': 904,
#  'replacement': 905,
#  'sitting': 906,
#  'lover': 907,
#  'alone': 908,
#  'cashews': 909,
#  'gourmet': 910,
#  'types': 911,
#  'brewed': 912,
#  'fill': 913,
#  'quantity': 914,
#  'number': 915,
#  'lbs': 916,
#  'chance': 917,
#  'paying': 918,
#  'reviewer': 919,
#  'standard': 920,
#  'reviewers': 921,
#  'shelf': 922,
#  'cause': 923,
#  'directions': 924,
#  'sauces': 925,
#  'birthday': 926,
#  'jars': 927,
#  'potatoes': 928,
#  'restaurant': 929,
#  'notice': 930,
#  'vegetables': 931,
#  'helped': 932,
#  'dressing': 933,
#  'sort': 934,
#  'dessert': 935,
#  'double': 936,
#  'portion': 937,
#  'bitterness': 938,
#  'disappointing': 939,
#  'straight': 940,
#  'lasts': 941,
#  'eater': 942,
#  'blood': 943,
#  'knew': 944,
#  'mustard': 945,
#  'school': 946,
#  'outside': 947,
#  'lost': 948,
#  'clear': 949,
#  'website': 950,
#  'personally': 951,
#  'issue': 952,
#  'covered': 953,
#  'beautiful': 954,
#  'selling': 955,
#  'pour': 956,
#  'cheddar': 957,
#  'gotten': 958,
#  'unique': 959,
#  'careful': 960,
#  'bits': 961,
#  'appreciate': 962,
#  'busy': 963,
#  'boost': 964,
#  'threw': 965,
#  'gummi': 966,
#  'pounds': 967,
#  'heard': 968,
#  'turn': 969,
#  'bodied': 970,
#  'fridge': 971,
#  'blends': 972,
#  'brewing': 973,
#  'surprise': 974,
#  'sweetened': 975,
#  'sensitive': 976,
#  'grains': 977,
#  'tart': 978,
#  'listed': 979,
#  'wants': 980,
#  'usa': 981,
#  'hazelnut': 982,
#  'subtle': 983,
#  'nasty': 984,
#  'tired': 985,
#  'instructions': 986,
#  'traditional': 987,
#  'avoid': 988,
#  'tuna': 989,
#  'english': 990,
#  'brownies': 991,
#  'carbonated': 992,
#  'cool': 993,
#  'lab': 994,
#  'whenever': 995,
#  'fair': 996,
#  'child': 997,
#  'pops': 998,
#  'tomato': 999,
#  'soups': 1000,
#  ...}

# %%
src_tokenizer.index_word    # 딕셔너리 타입: {인덱스 번호: '단어'}
# Out:
# {1: 'like',
#  2: 'good',
#  3: 'great',
#  4: 'taste',
#  5: 'product',
#  6: 'love',
#  7: 'one',
#  8: 'coffee',
#  9: 'flavor',
#  10: 'would',
#  11: 'tea',
#  12: 'really',
#  13: 'get',
#  14: 'amazon',
#  15: 'best',
#  16: 'price',
#  17: 'buy',
#  18: 'much',
#  19: 'food',
#  20: 'time',
#  21: 'find',
#  22: 'use',
#  23: 'little',
#  24: 'tried',
#  25: 'better',
#  26: 'well',
#  27: 'also',
#  28: 'make',
#  29: 'chocolate',
#  30: 'try',
#  31: 'dog',
#  32: 'eat',
#  33: 'even',
#  34: 'bought',
#  35: 'sweet',
#  36: 'delicious',
#  37: 'found',
#  38: 'order',
#  39: 'could',
#  40: 'drink',
#  41: 'cup',
#  42: 'recommend',
#  43: 'tastes',
#  44: 'loves',
#  45: 'used',
#  46: 'bag',
#  47: 'sugar',
#  48: 'favorite',
#  49: 'store',
#  50: 'cannot',
#  51: 'first',
#  52: 'free',
#  53: 'nice',
#  54: 'way',
#  55: 'made',
#  56: 'go',
#  57: 'box',
#  58: 'perfect',
#  59: 'got',
#  60: 'day',
#  61: 'bit',
#  62: 'mix',
#  63: 'since',
#  64: 'think',
#  65: 'easy',
#  66: 'dogs',
#  67: 'water',
#  68: 'ordered',
#  69: 'snack',
#  70: 'ever',
#  71: 'give',
#  72: 'two',
#  73: 'hot',
#  74: 'many',
#  75: 'flavors',
#  76: 'every',
#  77: 'still',
#  78: 'never',
#  79: 'makes',
#  80: 'treats',
#  81: 'stuff',
#  82: 'always',
#  83: 'healthy',
#  84: 'without',
#  85: 'know',
#  86: 'brand',
#  87: 'right',
#  88: 'quality',
#  89: 'fresh',
#  90: 'want',
#  91: 'tasty',
#  92: 'definitely',
#  93: 'hard',
#  94: 'years',
#  95: 'keep',
#  96: 'strong',
#  97: 'something',
#  98: 'lot',
#  99: 'add',
#  100: 'buying',
#  101: 'enjoy',
#  102: 'wonderful',
#  103: 'small',
#  104: 'happy',
#  105: 'treat',
#  106: 'enough',
#  107: 'milk',
#  108: 'old',
#  109: 'bad',
#  110: 'excellent',
#  111: 'less',
#  112: 'local',
#  113: 'say',
#  114: 'chips',
#  115: 'highly',
#  116: 'different',
#  117: 'organic',
#  118: 'however',
#  119: 'purchase',
#  120: 'shipping',
#  121: 'need',
#  122: 'eating',
#  123: 'sure',
#  124: 'regular',
#  125: 'far',
#  126: 'size',
#  127: 'long',
#  128: 'looking',
#  129: 'products',
#  130: 'tasting',
#  131: 'put',
#  132: 'thought',
#  133: 'stores',
#  134: 'pack',
#  135: 'tasted',
#  136: 'back',
#  137: 'salt',
#  138: 'using',
#  139: 'though',
#  140: 'pretty',
#  141: 'whole',
#  142: 'purchased',
#  143: 'bags',
#  144: 'loved',
#  145: 'cups',
#  146: 'work',
#  147: 'bars',
#  148: 'worth',
#  149: 'cookies',
#  150: 'high',
#  151: 'texture',
#  152: 'gluten',
#  153: 'package',
#  154: 'low',
#  155: 'ingredients',
#  156: 'grocery',
#  157: 'green',
#  158: 'family',
#  159: 'thing',
#  160: 'sauce',
#  161: 'arrived',
#  162: 'big',
#  163: 'quite',
#  164: 'popcorn',
#  165: 'going',
#  166: 'rice',
#  167: 'last',
#  168: 'received',
#  169: 'year',
#  170: 'take',
#  171: 'expensive',
#  172: 'came',
#  173: 'candy',
#  174: 'actually',
#  175: 'anything',
#  176: 'real',
#  177: 'item',
#  178: 'feel',
#  179: 'cat',
#  180: 'cereal',
#  181: 'oil',
#  182: 'almost',
#  183: 'see',
#  184: 'calories',
#  185: 'dark',
#  186: 'natural',
#  187: 'husband',
#  188: 'chicken',
#  189: 'full',
#  190: 'money',
#  191: 'another',
#  192: 'new',
#  193: 'blend',
#  194: 'butter',
#  195: 'trying',
#  196: 'bar',
#  197: 'around',
#  198: 'kids',
#  199: 'smell',
#  200: 'morning',
#  201: 'getting',
#  202: 'disappointed',
#  203: 'people',
#  204: 'brands',
#  205: 'fruit',
#  206: 'amount',
#  207: 'coconut',
#  208: 'absolutely',
#  209: 'several',
#  210: 'home',
#  211: 'half',
#  212: 'away',
#  213: 'cheese',
#  214: 'diet',
#  215: 'bitter',
#  216: 'fast',
#  217: 'able',
#  218: 'added',
#  219: 'wish',
#  220: 'usually',
#  221: 'dry',
#  222: 'smooth',
#  223: 'ones',
#  224: 'available',
#  225: 'oz',
#  226: 'light',
#  227: 'us',
#  228: 'deal',
#  229: 'kind',
#  230: 'nothing',
#  231: 'works',
#  232: 'foods',
#  233: 'fat',
#  234: 'liked',
#  235: 'may',
#  236: 'breakfast',
#  237: 'come',
#  238: 'flavored',
#  239: 'ordering',
#  240: 'days',
#  241: 'probably',
#  242: 'company',
#  243: 'per',
#  244: 'problem',
#  245: 'cats',
#  246: 'case',
#  247: 'quick',
#  248: 'cheaper',
#  249: 'making',
#  250: 'save',
#  251: 'months',
#  252: 'black',
#  253: 'things',
#  254: 'said',
#  255: 'fine',
#  256: 'quickly',
#  257: 'boxes',
#  258: 'bread',
#  259: 'gift',
#  260: 'reviews',
#  261: 'peanut',
#  262: 'pasta',
#  263: 'glad',
#  264: 'seems',
#  265: 'variety',
#  266: 'large',
#  267: 'bottle',
#  268: 'honey',
#  269: 'especially',
#  270: 'recommended',
#  271: 'son',
#  272: 'packaging',
#  273: 'comes',
#  274: 'house',
#  275: 'rich',
#  276: 'juice',
#  277: 'others',
#  278: 'gave',
#  279: 'look',
#  280: 'prefer',
#  281: 'protein',
#  282: 'drinking',
#  283: 'instead',
#  284: 'three',
#  285: 'spicy',
#  286: 'anyone',
#  287: 'thank',
#  288: 'daughter',
#  289: 'syrup',
#  290: 'cream',
#  291: 'amazing',
#  292: 'top',
#  293: 'thanks',
#  294: 'roast',
#  295: 'yummy',
#  296: 'everyone',
#  297: 'energy',
#  298: 'stars',
#  299: 'meal',
#  300: 'white',
#  301: 'soft',
#  302: 'wanted',
#  303: 'cans',
#  304: 'likes',
#  305: 'times',
#  306: 'teeth',
#  307: 'vanilla',
#  308: 'might',
#  309: 'seem',
#  310: 'must',
#  311: 'fan',
#  312: 'month',
#  313: 'extra',
#  314: 'maybe',
#  315: 'next',
#  316: 'ginger',
#  317: 'fact',
#  318: 'either',
#  319: 'health',
#  320: 'pieces',
#  321: 'else',
#  322: 'plus',
#  323: 'awesome',
#  324: 'everything',
#  325: 'enjoyed',
#  326: 'value',
#  327: 'salty',
#  328: 'baby',
#  329: 'teas',
#  330: 'friends',
#  331: 'crunchy',
#  332: 'cost',
#  333: 'nuts',
#  334: 'bold',
#  335: 'keurig',
#  336: 'least',
#  337: 'beans',
#  338: 'super',
#  339: 'couple',
#  340: 'longer',
#  341: 'went',
#  342: 'yet',
#  343: 'market',
#  344: 'online',
#  345: 'open',
#  346: 'ice',
#  347: 'ago',
#  348: 'plastic',
#  349: 'started',
#  350: 'soup',
#  351: 'decided',
#  352: 'chew',
#  353: 'took',
#  354: 'help',
#  355: 'pleased',
#  356: 'noodles',
#  357: 'although',
#  358: 'cold',
#  359: 'mouth',
#  360: 'ok',
#  361: 'corn',
#  362: 'alternative',
#  363: 'pepper',
#  364: 'second',
#  365: 'minutes',
#  366: 'week',
#  367: 'expected',
#  368: 'review',
#  369: 'flavorful',
#  370: 'service',
#  371: 'lemon',
#  372: 'says',
#  373: 'jerky',
#  374: 'read',
#  375: 'delivery',
#  376: 'snacks',
#  377: 'cookie',
#  378: 'cocoa',
#  379: 'let',
#  380: 'drinks',
#  381: 'type',
#  382: 'plain',
#  383: 'soda',
#  384: 'rather',
#  385: 'wife',
#  386: 'ounce',
#  387: 'crackers',
#  388: 'weight',
#  389: 'wheat',
#  390: 'exactly',
#  391: 'machine',
#  392: 'goes',
#  393: 'powder',
#  394: 'gets',
#  395: 'beef',
#  396: 'cook',
#  397: 'aroma',
#  398: 'surprised',
#  399: 'decaf',
#  400: 'french',
#  401: 'side',
#  402: 'special',
#  403: 'cooking',
#  404: 'problems',
#  405: 'sometimes',
#  406: 'version',
#  407: 'meat',
#  408: 'mixed',
#  409: 'opened',
#  410: 'smaller',
#  411: 'packaged',
#  412: 'convenient',
#  413: 'red',
#  414: 'easily',
#  415: 'guess',
#  416: 'friend',
#  417: 'wrong',
#  418: 'choice',
#  419: 'part',
#  420: 'aftertaste',
#  421: 'refreshing',
#  422: 'shipped',
#  423: 'picky',
#  424: 'clean',
#  425: 'tell',
#  426: 'fantastic',
#  427: 'believe',
#  428: 'serving',
#  429: 'place',
#  430: 'dried',
#  431: 'care',
#  432: 'brown',
#  433: 'difference',
#  434: 'artificial',
#  435: 'orange',
#  436: 'cinnamon',
#  437: 'subscribe',
#  438: 'cake',
#  439: 'hand',
#  440: 'oatmeal',
#  441: 'mild',
#  442: 'smells',
#  443: 'giving',
#  444: 'packs',
#  445: 'christmas',
#  446: 'left',
#  447: 'container',
#  448: 'lots',
#  449: 'slightly',
#  450: 'reason',
#  451: 'potato',
#  452: 'live',
#  453: 'often',
#  454: 'brew',
#  455: 'huge',
#  456: 'seeds',
#  457: 'recently',
#  458: 'bite',
#  459: 'chewy',
#  460: 'recipe',
#  461: 'spice',
#  462: 'etc',
#  463: 'continue',
#  464: 'line',
#  465: 'bottles',
#  466: 'run',
#  467: 'stomach',
#  468: 'bulk',
#  469: 'sent',
#  470: 'coffees',
#  471: 'looks',
#  472: 'fiber',
#  473: 'almonds',
#  474: 'cherry',
#  475: 'pop',
#  476: 'pay',
#  477: 'looked',
#  478: 'cut',
#  479: 'dinner',
#  480: 'gives',
#  481: 'seller',
#  482: 'needed',
#  483: 'iced',
#  484: 'end',
#  485: 'life',
#  486: 'delivered',
#  487: 'simply',
#  488: 'chai',
#  489: 'compared',
#  490: 'carry',
#  491: 'excited',
#  492: 'stick',
#  493: 'overall',
#  494: 'starbucks',
#  495: 'filling',
#  496: 'packages',
#  497: 'eaten',
#  498: 'past',
#  499: 'original',
#  500: 'start',
#  501: 'calorie',
#  502: 'toy',
#  503: 'apple',
#  504: 'ate',
#  505: 'hope',
#  506: 'helps',
#  507: 'date',
#  508: 'waste',
#  509: 'unfortunately',
#  510: 'weeks',
#  511: 'close',
#  512: 'takes',
#  513: 'com',
#  514: 'night',
#  515: 'lunch',
#  516: 'gum',
#  517: 'items',
#  518: 'chip',
#  519: 'heat',
#  520: 'granola',
#  521: 'purchasing',
#  522: 'keeps',
#  523: 'weak',
#  524: 'larger',
#  525: 'creamy',
#  526: 'saw',
#  527: 'jar',
#  528: 'healthier',
#  529: 'canned',
#  530: 'needs',
#  531: 'someone',
#  532: 'soon',
#  533: 'color',
#  534: 'soy',
#  535: 'wait',
#  536: 'idea',
#  537: 'feed',
#  538: 'course',
#  539: 'gone',
#  540: 'packed',
#  541: 'olive',
#  542: 'single',
#  543: 'similar',
#  544: 'broken',
#  545: 'along',
#  546: 'sold',
#  547: 'already',
#  548: 'stale',
#  549: 'four',
#  550: 'extremely',
#  551: 'pumpkin',
#  552: 'sweetness',
#  553: 'seasoning',
#  554: 'stock',
#  555: 'nut',
#  556: 'caffeine',
#  557: 'condition',
#  558: 'change',
#  559: 'salad',
#  560: 'crunch',
#  561: 'finally',
#  562: 'hours',
#  563: 'microwave',
#  564: 'consistency',
#  565: 'expect',
#  566: 'please',
#  567: 'given',
#  568: 'anywhere',
#  569: 'inside',
#  570: 'fish',
#  571: 'beat',
#  572: 'pet',
#  573: 'hooked',
#  574: 'non',
#  575: 'daily',
#  576: 'mine',
#  577: 'star',
#  578: 'pound',
#  579: 'espresso',
#  580: 'medium',
#  581: 'experience',
#  582: 'baking',
#  583: 'stop',
#  584: 'shipment',
#  585: 'locally',
#  586: 'flour',
#  587: 'together',
#  588: 'maker',
#  589: 'cheap',
#  590: 'training',
#  591: 'hair',
#  592: 'within',
#  593: 'leave',
#  594: 'certainly',
#  595: 'packets',
#  596: 'eats',
#  597: 'lb',
#  598: 'pork',
#  599: 'yogurt',
#  600: 'stopped',
#  601: 'totally',
#  602: 'greenies',
#  603: 'anymore',
#  604: 'reasonable',
#  605: 'difficult',
#  606: 'future',
#  607: 'rest',
#  608: 'thick',
#  609: 'banana',
#  610: 'sour',
#  611: 'due',
#  612: 'chews',
#  613: 'adding',
#  614: 'instant',
#  615: 'almond',
#  616: 'yum',
#  617: 'worked',
#  618: 'list',
#  619: 'formula',
#  620: 'vet',
#  621: 'area',
#  622: 'hit',
#  623: 'name',
#  624: 'bowl',
#  625: 'puppy',
#  626: 'satisfying',
#  627: 'break',
#  628: 'perfectly',
#  629: 'easier',
#  630: 'chili',
#  631: 'kick',
#  632: 'combination',
#  633: 'licorice',
#  634: 'opinion',
#  635: 'based',
#  636: 'ground',
#  637: 'completely',
#  638: 'done',
#  639: 'wow',
#  640: 'sale',
#  641: 'sodium',
#  642: 'bland',
#  643: 'moist',
#  644: 'fun',
#  645: 'pure',
#  646: 'shop',
#  647: 'throw',
#  648: 'substitute',
#  649: 'sell',
#  650: 'true',
#  651: 'crazy',
#  652: 'mind',
#  653: 'baked',
#  654: 'carb',
#  655: 'leaves',
#  656: 'world',
#  657: 'spices',
#  658: 'finding',
#  659: 'count',
#  660: 'satisfied',
#  661: 'recipes',
#  662: 'pot',
#  663: 'raw',
#  664: 'stay',
#  665: 'ingredient',
#  666: 'decent',
#  667: 'truly',
#  668: 'today',
#  669: 'pricey',
#  670: 'finish',
#  671: 'hoping',
#  672: 'horrible',
#  673: 'seemed',
#  674: 'okay',
#  675: 'mint',
#  676: 'addition',
#  677: 'five',
#  678: 'grain',
#  679: 'lower',
#  680: 'become',
#  681: 'pick',
#  682: 'costco',
#  683: 'blue',
#  684: 'summer',
#  685: 'mixes',
#  686: 'dish',
#  687: 'option',
#  688: 'simple',
#  689: 'twice',
#  690: 'bottom',
#  691: 'contains',
#  692: 'batch',
#  693: 'tiny',
#  694: 'none',
#  695: 'expecting',
#  696: 'mess',
#  697: 'hint',
#  698: 'yes',
#  699: 'favorites',
#  700: 'piece',
#  701: 'told',
#  702: 'entire',
#  703: 'newman',
#  704: 'thin',
#  705: 'normally',
#  706: 'grey',
#  707: 'customer',
#  708: 'content',
#  709: 'maple',
#  710: 'cooked',
#  711: 'mom',
#  712: 'later',
#  713: 'priced',
#  714: 'hour',
#  715: 'packet',
#  716: 'forward',
#  717: 'discovered',
#  718: 'particular',
#  719: 'veggies',
#  720: 'plan',
#  721: 'pleasant',
#  722: 'description',
#  723: 'noticed',
#  724: 'strawberry',
#  725: 'glass',
#  726: 'body',
#  727: 'six',
#  728: 'drinker',
#  729: 'impressed',
#  730: 'terrible',
#  731: 'remember',
#  732: 'sweetener',
#  733: 'adds',
#  734: 'pancakes',
#  735: 'acid',
#  736: 'varieties',
#  737: 'awful',
#  738: 'pie',
#  739: 'loose',
#  740: 'warm',
#  741: 'dont',
#  742: 'normal',
#  743: 'serve',
#  744: 'unless',
#  745: 'seen',
#  746: 'turned',
#  747: 'door',
#  748: 'issues',
#  749: 'bones',
#  750: 'candies',
#  751: 'supermarket',
#  752: 'prices',
#  753: 'label',
#  754: 'switch',
#  755: 'return',
#  756: 'otherwise',
#  757: 'everyday',
#  758: 'paid',
#  759: 'stronger',
#  760: 'called',
#  761: 'chocolates',
#  762: 'anyway',
#  763: 'job',
#  764: 'oh',
#  765: 'salmon',
#  766: 'earl',
#  767: 'italian',
#  768: 'roasted',
#  769: 'office',
#  770: 'garlic',
#  771: 'bears',
#  772: 'ready',
#  773: 'individual',
#  774: 'pods',
#  775: 'skin',
#  776: 'caramel',
#  777: 'subscription',
#  778: 'fit',
#  779: 'shake',
#  780: 'bean',
#  781: 'agree',
#  782: 'immediately',
#  783: 'uses',
#  784: 'felt',
#  785: 'thinking',
#  786: 'mountain',
#  787: 'shape',
#  788: 'stevia',
#  789: 'beverage',
#  790: 'bring',
#  791: 'carrying',
#  792: 'style',
#  793: 'meals',
#  794: 'heavy',
#  795: 'flavoring',
#  796: 'taking',
#  797: 'ask',
#  798: 'contain',
#  799: 'homemade',
#  800: 'overly',
#  801: 'feeling',
#  802: 'ship',
#  803: 'unlike',
#  804: 'vinegar',
#  805: 'convenience',
#  806: 'somewhat',
#  807: 'thrilled',
#  808: 'party',
#  809: 'allergies',
#  810: 'feeding',
#  811: 'complaint',
#  812: 'check',
#  813: 'matter',
#  814: 'nicely',
#  815: 'touch',
#  816: 'results',
#  817: 'peanuts',
#  818: 'liquid',
#  819: 'crisp',
#  820: 'breath',
#  821: 'chewing',
#  822: 'benefits',
#  823: 'changed',
#  824: 'nearly',
#  825: 'carbs',
#  826: 'sealed',
#  827: 'hands',
#  828: 'worst',
#  829: 'except',
#  830: 'person',
#  831: 'point',
#  832: 'pouch',
#  833: 'overpowering',
#  834: 'supply',
#  835: 'wrapped',
#  836: 'lime',
#  837: 'sticks',
#  838: 'afternoon',
#  839: 'plenty',
#  840: 'reading',
#  841: 'set',
#  842: 'sorry',
#  843: 'sick',
#  844: 'send',
#  845: 'sea',
#  846: 'trouble',
#  847: 'call',
#  848: 'mother',
#  849: 'bigger',
#  850: 'mostly',
#  851: 'usual',
#  852: 'raspberry',
#  853: 'grams',
#  854: 'bbq',
#  855: 'eggs',
#  856: 'source',
#  857: 'supposed',
#  858: 'craving',
#  859: 'bake',
#  860: 'near',
#  861: 'fairly',
#  862: 'crispy',
#  863: 'nutrition',
#  864: 'mango',
#  865: 'prepare',
#  866: 'kinds',
#  867: 'expiration',
#  868: 'gf',
#  869: 'perhaps',
#  870: 'balance',
#  871: 'short',
#  872: 'berry',
#  873: 'dented',
#  874: 'gummy',
#  875: 'kitchen',
#  876: 'stuck',
#  877: 'running',
#  878: 'picture',
#  879: 'weird',
#  880: 'biscuits',
#  881: 'means',
#  882: 'served',
#  883: 'pizza',
#  884: 'walmart',
#  885: 'dishes',
#  886: 'higher',
#  887: 'hate',
#  888: 'jelly',
#  889: 'alot',
#  890: 'addicted',
#  891: 'china',
#  892: 'kid',
#  893: 'children',
#  894: 'brought',
#  895: 'ended',
#  896: 'sample',
#  897: 'working',
#  898: 'plant',
#  899: 'kept',
#  900: 'share',
#  901: 'pleasantly',
#  902: 'coming',
#  903: 'enjoys',
#  904: 'whatever',
#  905: 'replacement',
#  906: 'sitting',
#  907: 'lover',
#  908: 'alone',
#  909: 'cashews',
#  910: 'gourmet',
#  911: 'types',
#  912: 'brewed',
#  913: 'fill',
#  914: 'quantity',
#  915: 'number',
#  916: 'lbs',
#  917: 'chance',
#  918: 'paying',
#  919: 'reviewer',
#  920: 'standard',
#  921: 'reviewers',
#  922: 'shelf',
#  923: 'cause',
#  924: 'directions',
#  925: 'sauces',
#  926: 'birthday',
#  927: 'jars',
#  928: 'potatoes',
#  929: 'restaurant',
#  930: 'notice',
#  931: 'vegetables',
#  932: 'helped',
#  933: 'dressing',
#  934: 'sort',
#  935: 'dessert',
#  936: 'double',
#  937: 'portion',
#  938: 'bitterness',
#  939: 'disappointing',
#  940: 'straight',
#  941: 'lasts',
#  942: 'eater',
#  943: 'blood',
#  944: 'knew',
#  945: 'mustard',
#  946: 'school',
#  947: 'outside',
#  948: 'lost',
#  949: 'clear',
#  950: 'website',
#  951: 'personally',
#  952: 'issue',
#  953: 'covered',
#  954: 'beautiful',
#  955: 'selling',
#  956: 'pour',
#  957: 'cheddar',
#  958: 'gotten',
#  959: 'unique',
#  960: 'careful',
#  961: 'bits',
#  962: 'appreciate',
#  963: 'busy',
#  964: 'boost',
#  965: 'threw',
#  966: 'gummi',
#  967: 'pounds',
#  968: 'heard',
#  969: 'turn',
#  970: 'bodied',
#  971: 'fridge',
#  972: 'blends',
#  973: 'brewing',
#  974: 'surprise',
#  975: 'sweetened',
#  976: 'sensitive',
#  977: 'grains',
#  978: 'tart',
#  979: 'listed',
#  980: 'wants',
#  981: 'usa',
#  982: 'hazelnut',
#  983: 'subtle',
#  984: 'nasty',
#  985: 'tired',
#  986: 'instructions',
#  987: 'traditional',
#  988: 'avoid',
#  989: 'tuna',
#  990: 'english',
#  991: 'brownies',
#  992: 'carbonated',
#  993: 'cool',
#  994: 'lab',
#  995: 'whenever',
#  996: 'fair',
#  997: 'child',
#  998: 'pops',
#  999: 'tomato',
#  1000: 'soups',
#  ...}

# %%
src_tokenizer.word_counts   # OrderedDict 타입. ('단어', 빈도수) 형태의 튜플로 이루어진 리스트.
# Out:
# OrderedDict([('great', 14338),
#              ('lemon', 660),
#              ('lime', 262),
#              ('oil', 1343),
#              ('tasted', 1684),
#              ('friends', 793),
#              ('place', 558),
#              ('worth', 1572),
#              ('every', 2412),
#              ('penny', 100),
#              ('nice', 2963),
#              ('taste', 11564),
#              ('goes', 619),
#              ('well', 4461),
#              ('salads', 204),
#              ('cakes', 152),
#              ('definitely', 2093),
#              ('recommend', 3287),
#              ('product', 10791),
#              ('chips', 1897),
#              ('pretty', 1663),
#              ('delicious', 3451),
#              ('even', 3903),
#              ('original', 481),
#              ('flavor', 9803),
#              ('nothing', 1053),
#              ('good', 14825),
#              ('doritos', 13),
#              ('also', 4453),
#              ('fried', 140),
#              ('either', 819),
#              ('balances', 12),
#              ('snack', 2467),
#              ('times', 840),
#              ('day', 2548),
#              ('favorite', 3124),
#              ('lower', 341),
#              ('calorie', 480),
#              ('drink', 3307),
#              ('healthy', 2260),
#              ('refreshing', 564),
#              ('feel', 1359),
#              ('guilty', 117),
#              ('drinking', 905),
#              ('much', 5610),
#              ('sugar', 3140),
#              ('little', 5066),
#              ('mellow', 102),
#              ('pumpkin', 433),
#              ('pie', 309),
#              ('top', 863),
#              ('brew', 527),
#              ('picks', 13),
#              ('enough', 1956),
#              ('though', 1667),
#              ('overall', 488),
#              ('coffee', 9912),
#              ('corn', 673),
#              ('tough', 163),
#              ('pop', 508),
#              ('need', 1802),
#              ('sit', 158),
#              ('paper', 173),
#              ('towel', 16),
#              ('one', 9990),
#              ('hand', 550),
#              ('spit', 74),
#              ('kernels', 162),
#              ('buying', 2031),
#              ('tried', 4843),
#              ('gummy', 248),
#              ('bears', 290),
#              ('local', 1919),
#              ('drug', 22),
#              ('store', 3100),
#              ('hooked', 408),
#              ('texture', 1537),
#              ('kept', 242),
#              ('coming', 241),
#              ('back', 1682),
#              ('would', 9204),
#              ('try', 4177),
#              ('generic', 56),
#              ('brand', 2205),
#              ('brands', 1202),
#              ('shelve', 2),
#              ('step', 85),
#              ('haribo', 162),
#              ('matter', 273),
#              ('fact', 821),
#              ('go', 2792),
#              ('get', 6460),
#              ('highly', 1890),
#              ('gold', 170),
#              ('enjoy', 1990),
#              ('love', 10397),
#              ('drawer', 76),
#              ('keurig', 785),
#              ('cuisinart', 23),
#              ('coffeemaker', 24),
#              ('fits', 143),
#              ('perfectly', 368),
#              ('holds', 115),
#              ('cups', 1590),
#              ('always', 2271),
#              ('many', 2429),
#              ('options', 124),
#              ('hot', 2441),
#              ('beverages', 67),
#              ('right', 2202),
#              ('think', 2517),
#              ('looks', 516),
#              ('slides', 11),
#              ('easily', 573),
#              ('know', 2217),
#              ('could', 3340),
#              ('made', 2886),
#              ('simple', 337),
#              ('item', 1365),
#              ('better', 4616),
#              ('tasting', 1727),
#              ('stuff', 2284),
#              ('make', 4333),
#              ('cherry', 510),
#              ('malted', 7),
#              ('milk', 1955),
#              ('shakes', 135),
#              ('put', 1723),
#              ('breakfast', 1041),
#              ('cereal', 1344),
#              ('lemonade', 120),
#              ('comes', 925),
#              ('two', 2449),
#              ('pack', 1687),
#              ('long', 1757),
#              ('way', 2895),
#              ('ive', 88),
#              ('ordered', 2470),
#              ('several', 1171),
#              ('amazon', 6064),
#              ('course', 438),
#              ('searching', 152),
#              ('natural', 1286),
#              ('mix', 2537),
#              ('actually', 1379),
#              ('like', 15746),
#              ('bitter', 1124),
#              ('fresh', 2140),
#              ('squeezed', 23),
#              ('mean', 170),
#              ('time', 5154),
#              ('purchase', 1829),
#              ('newmans', 36),
#              ('ready', 290),
#              ('sweet', 3459),
#              ('blueberry', 169),
#              ('overbearing', 20),
#              ('yet', 759),
#              ('excellent', 1936),
#              ('especially', 948),
#              ('ice', 730),
#              ('cold', 680),
#              ('foamy', 8),
#              ('smaller', 583),
#              ('amount', 1187),
#              ('water', 2475),
#              ('first', 3050),
#              ('fill', 237),
#              ('glass', 315),
#              ('family', 1498),
#              ('loves', 3246),
#              ('cheese', 1134),
#              ('salt', 1676),
#              ('hard', 2084),
#              ('find', 5100),
#              ('stores', 1718),
#              ('happy', 1971),
#              ('found', 3405),
#              ('bought', 3669),
#              ('bottles', 519),
#              ('share', 242),
#              ('everyone', 858),
#              ('dog', 4101),
#              ('used', 3217),
#              ('thought', 1721),
#              ('giving', 542),
#              ('treat', 1961),
#              ('supplement', 113),
#              ('improve', 60),
#              ('arthritis', 44),
#              ('symptoms', 45),
#              ('liver', 121),
#              ('enzymes', 6),
#              ('elevated', 8),
#              ('becoming', 50),
#              ('less', 1922),
#              ('active', 57),
#              ('thirsty', 33),
#              ('thank', 879),
#              ('goodness', 172),
#              ('friend', 570),
#              ('sent', 517),
#              ('link', 49),
#              ('fda', 20),
#              ('warnings', 13),
#              ('since', 2533),
#              ('hundreds', 31),
#              ('dogs', 2491),
#              ('died', 42),
#              ('painful', 23),
#              ('expensive', 1389),
#              ('deaths', 2),
#              ('website', 221),
#              ('buy', 5782),
#              ('treats', 2308),
#              ('ok', 678),
#              ('miss', 188),
#              ('probably', 1033),
#              ('influences', 2),
#              ('feedback', 33),
#              ('simply', 492),
#              ('decaf', 605),
#              ('teas', 795),
#              ('never', 2357),
#              ('gets', 616),
#              ('point', 263),
#              ('anything', 1375),
#              ('weak', 452),
#              ('use', 5093),
#              ('bags', 1622),
#              ('said', 992),
#              ('using', 1674),
#              ('supplemental', 3),
#              ('tea', 8181),
#              ('bag', 3169),
#              ('add', 2043),
#              ('idea', 441),
#              ('wish', 1100),
#              ('development', 8),
#              ('tasty', 2133),
#              ('everything', 802),
#              ('second', 671),
#              ('continue', 520),
#              ('thanks', 863),
#              ('absolutely', 1177),
#              ('exquisite', 12),
#              ('far', 1768),
#              ('pleasant', 316),
#              ('green', 1508),
#              ('unreliable', 5),
#              ('tiny', 336),
#              ('pinch', 73),
#              ('healthier', 448),
#              ('table', 157),
#              ('plus', 807),
#              ('pink', 136),
#              ('packing', 147),
#              ('keeps', 453),
#              ('five', 343),
#              ('stars', 850),
#              ('pure', 363),
#              ('himalayan', 36),
#              ('approved', 24),
#              ('finely', 38),
#              ('ground', 366),
#              ('mm', 107),
#              ('pound', 406),
#              ('pleasing', 64),
#              ('eye', 83),
#              ('seems', 958),
#              ('packed', 437),
#              ('enjoyed', 801),
#              ('color', 443),
#              ('scheme', 1),
#              ('seem', 834),
#              ('drab', 3),
#              ('colors', 134),
#              ('pleased', 688),
#              ('contents', 137),
#              ('straight', 226),
#              ('strong', 2075),
#              ('aromatic', 81),
#              ('smell', 1213),
#              ('dark', 1293),
#              ('hint', 334),
#              ('sweetness', 433),
#              ('next', 823),
#              ('heated', 76),
#              ('cup', 3300),
#              ('microwave', 418),
#              ('consistent', 113),
#              ('results', 272),
#              ('surprisingly', 116),
#              ('canned', 447),
#              ('kids', 1219),
#              ('eaten', 484),
#              ('oatmeal', 548),
#              ('everyday', 297),
#              ('weather', 91),
#              ('turned', 305),
#              ('puts', 61),
#              ('warmth', 10),
#              ('filling', 487),
#              ('tummies', 12),
#              ('flavors', 2427),
#              ('loved', 1622),
#              ('apple', 474),
#              ('banana', 382),
#              ('subscription', 288),
#              ('meant', 73),
#              ('price', 5834),
#              ('convenient', 581),
#              ('winter', 181),
#              ('ending', 10),
#              ('cancelled', 41),
#              ('done', 365),
#              ('market', 735),
#              ('months', 1000),
#              ('recently', 525),
#              ('clearanced', 1),
#              ('source', 255),
#              ('heat', 461),
#              ('uncle', 28),
#              ('ben', 8),
#              ('brown', 557),
#              ('rice', 1442),
#              ('single', 436),
#              ('serving', 559),
#              ('salmon', 292),
#              ('pouch', 263),
#              ('makes', 2353),
#              ('dinner', 504),
#              ('finished', 170),
#              ('month', 830),
#              ('amazing', 869),
#              ('oranges', 20),
#              ('work', 1581),
#              ('days', 1035),
#              ('week', 669),
#              ('feeling', 278),
#              ('energized', 17),
#              ('alert', 32),
#              ('gives', 504),
#              ('gluten', 1536),
#              ('freer', 1),
#              ('chance', 235),
#              ('crunchy', 791),
#              ('fast', 1122),
#              ('professional', 37),
#              ('transaction', 56),
#              ('needed', 503),
#              ('ingredient', 350),
#              ('new', 1254),
#              ('recipe', 521),
#              ('uses', 283),
#              ('earthborn', 5),
#              ('best', 5926),
#              ('grain', 343),
#              ('free', 3046),
#              ('food', 5539),
#              ('reasonably', 141),
#              ('priced', 325),
#              ('dense', 111),
#              ('year', 1434),
#              ('old', 1953),
#              ('squeeze', 87),
#              ('applesauce', 67),
#              ('looking', 1736),
#              ('alternative', 673),
#              ('plum', 48),
#              ('baby', 797),
#              ('blends', 216),
#              ('eat', 4092),
#              ('grainy', 85),
#              ('bland', 364),
#              ('got', 2634),
#              ('variety', 955),
#              ('waters', 55),
#              ('really', 6595),
#              ('spearmint', 70),
#              ('calls', 73),
#              ('peppermint', 175),
#              ('candy', 1380),
#              ('mint', 344),
#              ('least', 785),
#              ('added', 1103),
#              ('stevia', 282),
#              ('helpedwith', 1),
#              ('arenot', 2),
#              ('want', 2140),
#              ('chocolate', 4321),
#              ('pasta', 964),
#              ('tastes', 3272),
#              ('amazingly', 74),
#              ('low', 1515),
#              ('carb', 356),
#              ('bet', 55),
#              ('able', 1121),
#              ('tell', 563),
#              ('difference', 557),
#              ('normal', 307),
#              ('dieting', 43),
#              ('diabetic', 166),
#              ('patients', 10),
#              ('carby', 2),
#              ('meal', 849),
#              ('downside', 112),
#              ('high', 1545),
#              ('tag', 31),
#              ('health', 815),
#              ('regret', 104),
#              ('truly', 348),
#              ('pleasantly', 242),
#              ('years', 2084),
#              ('glad', 962),
#              ('pancake', 137),
#              ('waffle', 98),
#              ('bar', 1228),
#              ('none', 336),
#              ('tossed', 65),
#              ('trying', 1232),
#              ('expectations', 153),
#              ('seemed', 345),
#              ('kind', 1059),
#              ('mushy', 127),
#              ('pasty', 20),
#              ('pricy', 52),
#              ('boot', 57),
#              ('available', 1077),
#              ('subscribe', 551),
#              ('save', 1002),
#              ('feature', 51),
#              ('coconut', 1179),
#              ('putting', 205),
#              ('together', 396),
#              ('match', 57),
#              ('heaven', 125),
#              ('became', 140),
#              ('pk', 17),
#              ('felt', 283),
#              ('may', 1042),
#              ('wanted', 845),
#              ('plain', 636),
#              ('mood', 75),
#              ('type', 637),
#              ('thing', 1496),
#              ('rather', 634),
#              ('daily', 407),
#              ('easier', 368),
#              ('rawhide', 154),
#              ('bones', 303),
#              ('peanut', 965),
#              ('butter', 1238),
#              ('gift', 971),
#              ('beautiful', 220),
#              ('teapot', 17),
#              ('teacup', 3),
#              ('set', 260),
#              ('white', 848),
#              ('black', 994),
#              ('close', 466),
#              ('giant', 59),
#              ('vanilla', 838),
#              ('almond', 378),
#              ('wafer', 46),
#              ('going', 1443),
#              ('soon', 444),
#              ('european', 50),
#              ('tradition', 34),
#              ('totally', 384),
#              ('clueless', 3),
#              ('saw', 449),
#              ('grocery', 1513),
#              ('earlier', 83),
#              ('decided', 699),
#              ('followed', 103),
#              ('instructions', 213),
#              ('viola', 7),
#              ('awesome', 804),
#              ('note', 200),
#              ('parmesan', 43),
#              ('romano', 4),
#              ('flavorful', 662),
#              ('cut', 505),
#              ('grass', 156),
#              ('mild', 544),
#              ('left', 536),
#              ('steeping', 33),
#              ('become', 341),
#              ('without', 2232),
#              ('sweeteners', 162),
#              ('loose', 309),
#              ('leaf', 193),
#              ('steeped', 30),
#              ('leaves', 356),
#              ('unfurl', 3),
#              ('slender', 3),
#              ('box', 2766),
#              ('mediocre', 37),
#              ('chocolates', 294),
#              ('cost', 790),
#              ('including', 197),
#              ('shipping', 1806),
#              ('sees', 45),
#              ('godiva', 28),
#              ('return', 300),
#              ('paying', 235),
#              ('twice', 337),
#              ('three', 899),
#              ('poms', 8),
#              ('greenies', 384),
#              ('expect', 417),
#              ('morning', 1210),
#              ('instant', 379),
#              ('versatile', 72),
#              ('cream', 870),
#              ('freezing', 22),
#              ('icing', 81),
#              ('mocha', 105),
#              ('beverage', 282),
#              ('bit', 2546),
#              ('acid', 311),
#              ('espresso', 405),
#              ('works', 1047),
#              ('wonderfully', 117),
#              ('barrista', 4),
#              ('latte', 127),
#              ('regular', 1792),
#              ('cooking', 599),
#              ('personally', 221),
#              ('jar', 449),
#              ('shelf', 233),
#              ('toy', 479),
#              ('lab', 211),
#              ('dropping', 16),
#              ('hardwood', 7),
#              ('floors', 15),
#              ('bottom', 337),
#              ('twist', 50),
#              ('part', 565),
#              ('broke', 107),
#              ('concept', 67),
#              ('plastic', 723),
#              ('brittle', 49),
#              ('company', 1030),
#              ('stand', 201),
#              ('behind', 60),
#              ('english', 212),
#              ('bulldog', 29),
#              ('problem', 1025),
#              ('chomping', 8),
#              ('newman', 331),
#              ('pay', 508),
#              ('name', 371),
#              ('budget', 49),
#              ('conscious', 49),
#              ('buyer', 89),
#              ('might', 837),
#              ('choose', 153),
#              ('cheaper', 1007),
#              ('sure', 1798),
#              ('organic', 1846),
#              ('pet', 409),
#              ('perhaps', 250),
#              ('certainly', 391),
#              ('cannot', 3089),
#              ('hurt', 64),
#              ('disappeared', 48),
#              ('quickly', 982),
#              ('eats', 388),
#              ('whiskey', 10),
#              ('sour', 381),
#              ('liquor', 43),
#              ('daiquiri', 2),
#              ('marguarita', 1),
#              ('marguaritas', 1),
#              ('involve', 6),
#              ('wedding', 96),
#              ('says', 660),
#              ('pretzels', 185),
#              ('container', 536),
#              ('granddaughter', 36),
#              ('blue', 339),
#              ('mixed', 588),
#              ('labeled', 75),
#              ('introduced', 174),
#              ('ago', 730),
#              ('popcorn', 1465),
#              ('house', 924),
#              ('ever', 2466),
#              ('unable', 133),
#              ('consistantly', 9),
#              ('friendly', 136),
#              ('neighborhood', 33),
#              ('chose', 72),
#              ('line', 520),
#              ('cases', 184),
#              ('jewell', 4),
#              ('lover', 240),
#              ('susan', 6),
#              ('bare', 18),
#              ('fruit', 1195),
#              ('baked', 357),
#              ('dried', 558),
#              ('anjou', 2),
#              ('pears', 52),
#              ('fuji', 13),
#              ('dellicious', 2),
#              ('chewy', 524),
#              ('satisfying', 369),
#              ('non', 408),
#              ('processed', 152),
#              ('tote', 7),
#              ('snacks', 650),
#              ('fit', 288),
#              ('bill', 176),
#              ('spicy', 888),
#              ('pick', 341),
#              ('aisle', 25),
#              ('hottest', 26),
#              ('chili', 368),
#              ('nibs', 10),
#              ('however', 1837),
#              ('must', 833),
#              ('talk', 38),
#              ('site', 201),
#              ('encountered', 31),
#              ('vacation', 79),
#              ('york', 44),
#              ('city', 64),
#              ('fairway', 2),
#              ('carries', 150),
#              ('half', 1146),
#              ('listed', 214),
#              ('fan', 832),
#              ('quick', 1012),
#              ('enjoying', 208),
#              ('within', 392),
#              ('couple', 772),
#              ('ordering', 1036),
#              ('deal', 1067),
#              ('costing', 18),
#              ('anywhere', 412),
#              ('due', 380),
#              ('demand', 18),
#              ('maranatha', 1),
#              ('yummy', 859),
#              ('stir', 176),
#              ('barry', 28),
#              ('blend', 1242),
#              ('boxes', 981),
#              ('retail', 128),
#              ('size', 1760),
#              ('shop', 363),
#              ('worn', 10),
#              ('simi', 1),
#              ('crushed', 118),
#              ('edges', 43),
#              ('experation', 3),
#              ('date', 470),
#              ('immeadiatly', 1),
#              ('gave', 916),
#              ('refund', 149),
#              ('florida', 62),
#              ('snyder', 14),
#              ('tends', 74),
#              ('according', 115),
#              ('buds', 185),
#              ('create', 76),
#              ('portion', 227),
#              ('control', 179),
#              ('value', 800),
#              ('throw', 363),
#              ('lunch', 464),
#              ('keep', 2079),
#              ('car', 198),
#              ('road', 97),
#              ('trips', 94),
#              ('ginger', 822),
#              ('dressing', 228),
#              ('japanese', 94),
#              ('restaurants', 104),
#              ('salad', 423),
#              ('juicer', 8),
#              ('machine', 621),
#              ('freshly', 62),
#              ('veggie', 109),
#              ('juices', 98),
#              ('utterly', 17),
#              ('disgusting', 155),
#              ('burn', 121),
#              ('palate', 64),
#              ('temperature', 75),
#              ('bad', 1944),
#              ('lingers', 20),
#              ('mouth', 680),
#              ('yes', 334),
#              ('slightly', 532),
#              ('knocks', 3),
#              ('recommended', 948),
#              ('coffees', 517),
#              ('smooth', 1085),
#              ('flavored', 1037),
#              ('definite', 63),
#              ('anytime', 122),
#              ('jasmine', 101),
#              ('sunflower', 99),
#              ('bonsai', 75),
#              ('tree', 198),
#              ('kit', 180),
#              ('evening', 207),
#              ('change', 424),
#              ('whole', 1649),
#              ('office', 291),
#              ('favor', 120),
#              ('overpowering', 263),
#              ('read', 654),
#              ('description', 316),
#              ('carefully', 81),
#              ('nowhere', 37),
#              ('see', 1333),
#              ('indication', 13),
#              ('descriptions', 12),
#              ('offered', 203),
#              ('clearer', 7),
#              ('confustion', 1),
#              ('purchasing', 457),
#              ('deceptive', 24),
#              ('assume', 72),
#              ('jamaican', 25),
#              ('oloves', 11),
#              ('finding', 353),
#              ('us', 1069),
#              ('thankful', 47),
#              ('tender', 155),
#              ('delicate', 112),
#              ('olives', 114),
#              ('ones', 1078),
#              ('spain', 20),
#              ('conveniently', 25),
#              ('packaged', 583),
#              ('taken', 112),
#              ('united', 29),
#              ('included', 161),
#              ('olove', 1),
#              ('fix', 198),
#              ('cats', 1023),
#              ('lick', 63),
#              ('last', 1439),
#              ('morsel', 10),
#              ('values', 13),
#              ('quality', 2177),
#              ('husband', 1280),
#              ('self', 85),
#              ('employed', 1),
#              ('spends', 13),
#              ('alot', 244),
#              ('takes', 465),
#              ('apples', 152),
#              ('nuts', 788),
#              ('given', 416),
#              ('away', 1135),
#              ('jobsites', 1),
#              ('guys', 116),
#              ('real', 1370),
#              ('peppercorns', 46),
#              ('indus', 2),
#              ('organics', 84),
#              ('pepper', 673),
#              ('another', 1260),
#              ('compare', 207),
#              ('tellicherry', 2),
#              ('lb', 388),
#              ('purity', 5),
#              ('punch', 103),
#              ('exceptionally', 33),
#              ('honestly', 170),
#              ('give', 2451),
#              ('disappointed', 1204),
#              ('rating', 140),
#              ('ratio', 49),
#              ('ounces', 187),
#              ('people', 1204),
#              ('theirlocal', 1),
#              ('overseas', 37),
#              ('jail', 1),
#              ('maybeout', 1),
#              ('minds', 5),
#              ('hostess', 32),
#              ('zingers', 1),
#              ('iced', 503),
#              ('cake', 551),
#              ('creamy', 450),
#              ('frosting', 105),
#              ('oz', 1074),
#              ('net', 64),
#              ('enjoyoh', 1),
#              ('thse', 2),
#              ('debbie', 8),
#              ('zebra', 2),
#              ('count', 353),
#              ('meow', 30),
#              ('hiss', 2),
#              ('purring', 3),
#              ('communication', 18),
#              ('cat', 1353),
#              ('alyssia', 1),
#              ('meows', 7),
#              ('henry', 7),
#              ('tries', 54),
#              ('take', 1425),
#              ('angry', 13),
#              ('help', 690),
#              ('purrs', 3),
#              ('delight', 115),
#              ('extra', 828),
#              ('cents', 160),
#              ('sales', 54),
#              ('tax', 60),
#              ('hassles', 5),
#              ('shopping', 151),
#              ('decent', 349),
#              ('started', 712),
#              ('virgin', 38),
#              ('olive', 437),
#              ('helps', 471),
#              ('cholesterol', 74),
#              ('effects', 124),
#              ('body', 314),
#              ('unlike', 277),
#              ('certain', 121),
#              ('veg', 15),
#              ('lard', 17),
#              ('spices', 355),
#              ('bread', 979),
#              ('fry', 86),
#              ('steak', 126),
#              ('lavazza', 70),
#              ('beans', 778),
#              ('wonderful', 1978),
#              ('crema', 61),
#              ('full', 1261),
#              ('bean', 286),
#              ('super', 777),
#              ('automatic', 87),
#              ('annd', 1),
#              ('clog', 7),
#              ('grinder', 88),
#              ('gran', 6),
#              ('filtro', 3),
#              ('decaffinated', 6),
#              ('reviewer', 235),
#              ('wife', 634),
#              ('neat', 37),
#              ('sending', 64),
#              ('co', 130),
#              ('workers', 56),
#              ('ooo', 3),
#              ('ahh', 4),
#              ('attention', 108),
#              ('unfortunatley', 7),
#              ('closed', 48),
#              ('hope', 472),
#              ('bloom', 18),
#              ('side', 602),
#              ('vase', 16),
#              ('nicer', 22),
#              ('picture', 247),
#              ('everthing', 3),
#              ('came', 1386),
#              ('stop', 403),
#              ('selling', 220),
#              ('upset', 196),
#              ('adjust', 44),
#              ('desire', 40),
#              ('foam', 33),
#              ('chai', 492),
#              ('products', 1735),
#              ('economical', 115),
#              ('usually', 1088),
#              ('lasts', 226),
#              ('different', 1877),
#              ('selection', 146),
#              ('includes', 52),
#              ('de', 79),
#              ('cafs', 1),
#              ('along', 435),
#              ('timothy', 95),
#              ('favorites', 334),
#              ('shipped', 564),
#              ('condition', 425),
#              ('exactly', 624),
#              ('lifestyle', 47),
#              ('bertolli', 3),
#              ('light', 1071),
#              ('seasoning', 432),
#              ('smidge', 5),
#              ('ingredients', 1515),
#              ('stronger', 295),
#              ('others', 918),
#              ('let', 641),
#              ('test', 143),
#              ('dean', 10),
#              ('jacob', 5),
#              ('dipping', 104),
#              ('order', 3350),
#              ('raisin', 97),
#              ('bran', 130),
#              ('key', 72),
#              ('availability', 26),
#              ('preference', 112),
#              ('apprehensive', 17),
#              ('growing', 122),
#              ('wheat', 628),
#              ('quite', 1469),
#              ('complicated', 15),
#              ('intention', 5),
#              ('grow', 130),
#              ('say', 1914),
#              ('directions', 231),
#              ('implicitly', 1),
#              ('tall', 48),
#              ('present', 138),
#              ('animals', 52),
#              ('today', 348),
#              ('eating', 1801),
#              ('interest', 79),
#              ('pans', 6),
#              ('dozen', 80),
#              ('perfect', 2652),
#              ('qualms', 2),
#              ('oberto', 25),
#              ('dad', 110),
#              ('essentially', 24),
#              ('limitless', 1),
#              ('supply', 263),
#              ('cocktail', 41),
#              ('pepperoni', 49),
#              ('steal', 36),
#              ('bars', 1574),
#              ('balance', 250),
#              ('syrup', 871),
#              ('unfortunately', 467),
#              ('although', 681),
#              ('expiration', 251),
#              ('third', 152),
#              ('mine', 407),
#              ('went', 765),
#              ('life', 495),
#              ('funny', 135),
#              ('metallic', 36),
#              ('substance', 38),
#              ('mold', 58),
#              ('wondering', 61),
#              ('refrigerating', 4),
#              ('prevented', 7),
#              ('beware', 173),
#              ('keeping', 192),
#              ('replaced', 72),
#              ('energy', 858),
#              ('boost', 218),
#              ('increase', 110),
#              ('iron', 77),
#              ('levels', 75),
#              ('fish', 411),
#              ('completely', 366),
#              ('serious', 77),
#              ('sort', 228),
#              ('candied', 23),
#              ('costs', 196),
#              ('fortune', 43),
#              ('end', 502),
#              ('supermarkets', 106),
#              ('deli', 27),
#              ('sections', 8),
#              ('asian', 141),
#              ('town', 157),
#              ('intend', 36),
#              ('wow', 365),
#              ('sold', 435),
#              ('breath', 269),
#              ('picky', 564),
#              ('eater', 226),
#              ('delivery', 654),
#              ('supposed', 255),
#              ('ripping', 11),
#              ('apart', 178),
#              ('separate', 70),
#              ('easy', 2501),
#              ('tore', 18),
#              ('leaking', 70),
#              ('piece', 334),
#              ('tad', 99),
#              ('flavorice', 2),
#              ('watch', 192),
#              ('cutting', 60),
#              ('sharp', 79),
#              ('purchased', 1631),
#              ('gifts', 190),
#              ('lovely', 165),
#              ...])

# %% [markdown]
# ## 5.2 Tokenizer 객체 저장했다가 다시 로드해 사용하는 방법

# %%
# [샘플코드] Tokenizer 객체의 모든 정보를(설정 정보 포함해서 데이터까지) 저장해 두었다가, 다시 로드해 Tokenizer 객체 생성하기
# 특히, 모델 훈련 후 추론 과정에서 필요함.
from tensorflow.keras.preprocessing.text import Tokenizer, tokenizer_from_json
import json

# 샘플 텍스트 데이터
texts = ["I love machine learning", "Deep learning is fun"]

# 토크나이저 생성 및 학습
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(texts)

# 토크나이저 정보를 JSON 형태로 변환 및 저장
json_string = tokenizer.to_json()
with open('tokenizer.json', 'w') as f:
    json.dump(json_string, f)

# 저장된 JSON 파일에서 토크나이저 로드
with open('tokenizer.json', 'r') as f:
    json_string = json.load(f)
loaded_tokenizer = tokenizer_from_json(json_string)
# Out:
# [[]]

# %%
# 토크나이저의 설정 정보 뿐 아니라 사전 데이터까지 모든 정보가 JSON 형식으로 저장됨.
json_string
# Out:
# '{"class_name": "Tokenizer", "config": {"num_words": 10000, "filters": "!\\"#$%&()*+,-./:;<=>?@[\\\\]^_`{|}~\\t\\n", "lower": true, "split": " ", "char_level": false, "oov_token": null, "document_count": 2, "word_counts": "{\\"i\\": 1, \\"love\\": 1, \\"machine\\": 1, \\"learning\\": 2, \\"deep\\": 1, \\"is\\": 1, \\"fun\\": 1}", "word_docs": "{\\"learning\\": 2, \\"i\\": 1, \\"machine\\": 1, \\"love\\": 1, \\"fun\\": 1, \\"is\\": 1, \\"deep\\": 1}", "index_docs": "{\\"1\\": 2, \\"2\\": 1, \\"4\\": 1, \\"3\\": 1, \\"7\\": 1, \\"6\\": 1, \\"5\\": 1}", "index_word": "{\\"1\\": \\"learning\\", \\"2\\": \\"i\\", \\"3\\": \\"love\\", \\"4\\": \\"machine\\", \\"5\\": \\"deep\\", \\"6\\": \\"is\\", \\"7\\": \\"fun\\"}", "word_index": "{\\"learning\\": 1, \\"i\\": 2, \\"love\\": 3, \\"machine\\": 4, \\"deep\\": 5, \\"is\\": 6, \\"fun\\": 7}"}}'

# %%
# 로드된 토크나이저를 이용하여 새로운 텍스트를 정수 시퀀스로 변환
new_text = "Natural Language love Processing and Deep learning"
sequence = loaded_tokenizer.texts_to_sequences([new_text])
print(sequence)
# Out:
# [[3, 5, 1]]
